# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data coupling for abiotic and biotic data based on location and date.
# ***
# _Authors: Rijk van der Meer and Ardjano Mark (Team jam.rs)._
#
# _Data: Dr. Louis Peperzak (NIOZ) and Rijkswaterstaat._
#
# _Project: Coupling plankton and abiotic long-term data sets._

# %% [markdown]
# ## Importing and preparing data.
# ***

# %%
abio_df = pd.read_excel('../../data/ABIO.xlsx', sheet_name='ABIO_SURF')
phyto_df = pd.read_excel('../../data/PHYTO.xlsx', sheet_name='PHYTO_SURF')
irradiance_df = pd.read_excel('../../data/Irradiance.xlsx', sheet_name='PAR')

# %%
display("Abiotic dataframe")
display(abio_df.head())
display("Phytoplankton dataframe")
display(phyto_df.head())
display("Irradiance dataframe")
display(irradiance_df.head())
# Out:
# 'Abiotic dataframe'
#    LOC_CODE  LOC      DATUMTIJDWAARDE     DATUM   TIJD  Year  Month  Day  \
# 0  GROOTGND  EDG   24-2-2017 15:29:00  20170224  '1529  2017      2   24
# 1  GROOTGND  EDG    1-4-2015 14:10:00  20150401  '1410  2015      4    1
# 2  GROOTGND  EDG   19-4-2016 15:38:00  20160419  '1538  2016      4   19
# 3   HUIBGOT  EDH  21-10-2004 05:59:00  20041021  '0559  2004     10   21
# 4  GROOTGND  EDG  13-10-1997 11:37:00  19971013  '1137  1997     10   13
#
#    Q_clndr  Q_eco         PAROMS PLT:REFVLAK VAR  BGC  Value_original  \
# 0        1      1  Zwevende stof      WATSGL  ZS  NaN          1380.0
# 1        2      2  Zwevende stof      WATSGL  ZS  NaN           732.0
# 2        2      2  Zwevende stof      WATSGL  ZS  NaN           712.0
# 3        4      4  Zwevende stof      WATSGL  ZS  NaN           710.0
# 4        4      4  Zwevende stof      WATSGL  ZS  NaN           677.0
#
#    Value_interm   VALUE  KWC   EHD
# 0        1380.0  1380.0    0  mg/l
# 1         732.0   732.0    0  mg/l
# 2         712.0   712.0    0  mg/l
# 3           NaN     NaN   56  mg/l
# 4         677.0   677.0   50  mg/l
# 'Phytoplankton dataframe'
#    LOC_CODE  LOC    WATERBODY       TYPE   DATE_SMP  YEAR  MONTH  DAY  \
# 0  GROOTGND  EDG  EEMSDOLLARD  ESTUARINE 2005-01-21   NaN    NaN  NaN
# 1  GROOTGND  EDG  EEMSDOLLARD  ESTUARINE 1994-01-25   NaN    NaN  NaN
# 2  GROOTGND  EDG  EEMSDOLLARD  ESTUARINE 1994-02-24   NaN    NaN  NaN
# 3  GROOTGND  EDG  EEMSDOLLARD  ESTUARINE 2001-03-22   NaN    NaN  NaN
# 4  GROOTGND  EDG  EEMSDOLLARD  ESTUARINE 2002-03-13   NaN    NaN  NaN
#
#    Q_clndr  Q_eco PROD_CODE                SPECIES SPEC GROUP  AMT_MEAS  \
# 0      NaN      1        OW  Actinocyclus normanii  Acn  DIAT       1.0
# 1      NaN      1    WATSGL  Actinocyclus normanii  Acn  DIAT       NaN
# 2      NaN      1    WATSGL  Actinocyclus normanii  Acn  DIAT       NaN
# 3      NaN      2        OW  Actinocyclus normanii  Acn  DIAT       1.0
# 4      NaN      2        OW  Actinocyclus normanii  Acn  DIAT       2.0
#
#             cL  LcL
# 0  5000.000000  NaN
# 1  2000.000000  NaN
# 2   485.000000  NaN
# 3   833.333333  NaN
# 4  4000.000000  NaN
# 'Irradiance dataframe'
#    YYYYMMDD      Q  YEAR  MONTH  PAR [J/m2d]  PAR [kJ/m2d]  kPAR_7d  kPAR_14d
# 0  19900101     49  1990      1     220500.0         220.5      NaN       NaN
# 1  19900102    161  1990      1     724500.0         724.5      NaN       NaN
# 2  19900103     75  1990      1     337500.0         337.5      NaN       NaN
# 3  19900104     51  1990      1     229500.0         229.5      NaN       NaN
# 4  19900105    196  1990      1     882000.0         882.0      NaN       NaN

# %% [markdown]
# ### Prepare abiotic data
# ***
# _Preparing the abiotic datasets on the following points_:
#
# - Extracting the unique variables measured in the dataset.
# - Extracting the different measurement locations in the dataset.
# - Move all measurements on a particular time and in a row together.

# %%
unique_PAROMS = list(abio_df.PAROMS.unique())
unique_VARS = list(abio_df.VAR.unique())
unique_tuple = list(zip(unique_PAROMS, unique_VARS))
display(unique_tuple)
# Out:
# [('Zwevende stof', 'ZS'),
#  ('Doorzicht', 'ZICHT'),
#  ('Temperatuur', 'T'),
#  ('silicaat', 'SiO2'),
#  ('Saliniteit', 'SALNTT'),
#  ('orthofosfaat', 'PO4'),
#  ('Zuurgraad', 'pH'),
#  ('nitraat', 'NO3'),
#  ('nitriet', 'NO2'),
#  ('ammonium', 'NH4'),
#  ('Extinctiecoefficient', 'E'),
#  ('chlorofyl-a', 'CHLFa')]

# %%
locations = list(abio_df["LOC_CODE"].unique())
locations_abv = list(abio_df["LOC"].unique())
locations_tuple = list(zip(locations, locations_abv))
locations_tuple
# Out:
# [('GROOTGND', 'EDG'),
#  ('HUIBGOT', 'EDH'),
#  ('SCHAARVODDL', 'WSO'),
#  ('DANTZGT', 'WZD'),
#  ('VLISSGBISSVH', 'WSV'),
#  ('MARSDND', 'WZM'),
#  ('HANSWGL', 'WSH'),
#  ('GOERE6', 'GOE6'),
#  ('WALCRN2', 'WA2'),
#  ('NOORDWK20', 'NW20'),
#  ('ROTTMPT3', 'RP3'),
#  ('SOELKKPDOT', 'VMS'),
#  ('NOORDWK2', 'NW2'),
#  ('WALCRN70', 'WA70'),
#  ('NOORDWK70', 'NW70'),
#  ('TERSLG10', 'TS10'),
#  ('NOORDWK10', 'NW10'),
#  ('WALCRN20', 'WA20'),
#  ('TERSLG4', 'TS4'),
#  ('ROTTMPT70', 'RP70'),
#  ('LODSGT', 'OSL'),
#  ('TERSLG135', 'TS135'),
#  ('ROTTMPT50', 'RP50'),
#  ('TERSLG235', 'TS235'),
#  ('DREISR', 'GMD'),
#  ('TERSLG100', 'TS100'),
#  ('TERSLG175', 'TS175')]

# %% [markdown]
# #### Move all rows from particular time and location into 1 row together.

# %%
def from_df_to_row_df(df: pd.DataFrame, location: str, time: str, col_list: list) -> pd.DataFrame:
    """
    Transforms a batch of rows to a single row. Both as pd.DataFrame type.

    Variables:
    df: Group of same location and same time in pd.DataFrame type.
    location: Location 
    time: Time 
    col_list = list of columns to use. The first two are the location and time.

    Output:
    A single row dataframe of type pd. DataFrame.
    """
    row_df = df
    row_df = row_df[col_list]

    measurements = list(zip(*(row_df[col] for col in col_list[2:])))
    measurements_dict = dict([t[:2] for t in measurements])
    loc, date = location, time

    row = pd.Series(measurements_dict)
    row[col_list[0]], row[col_list[1]] = loc, date

    final_df = row.to_frame().T

    return final_df

# %%
# group the DataFrame by 'LOC_CODE' and 'DATUMTIJDWAARDE'
# create a column list for the new dataframe
new_col_list = ["LOC_CODE", "DATUMTIJDWAARDE"] + unique_VARS
abio_flattened = pd.DataFrame(columns=new_col_list)

abio_grouped = abio_df.groupby(['LOC_CODE', 'DATUMTIJDWAARDE'])

# Iterate over the groups
for (location, time), group_df in abio_grouped:
    # 'location' and 'time' are the current group keys
    # 'group_df' is the DataFrame for the current group
    # Process the group_df as needed
    # print(group_df)
    group = from_df_to_row_df(group_df, location, time, col_list=["LOC_CODE", "DATUMTIJDWAARDE", 'VAR',"VALUE", "KWC", "EHD"])
    abio_flattened = pd.concat([abio_flattened, group], axis=0, join='outer')

# %% [markdown]
# #### Datumtijdwaarde
# ***
# - Turn col='datumtijdwaarde' into datetime type.
# - Extract time to a different column

# %%
abio_flattened["DATUMTIJDWAARDE"] = pd.to_datetime(abio_flattened["DATUMTIJDWAARDE"], format='mixed', dayfirst=True)

abio_flattened['TIJD'] = abio_flattened["DATUMTIJDWAARDE"].dt.time
abio_flattened['DATUM'] = abio_flattened["DATUMTIJDWAARDE"].dt.date

# %%
display(abio_flattened.head())
# Out:
#   LOC_CODE     DATUMTIJDWAARDE     ZS ZICHT      T       SiO2 SALNTT  \
# 0  DANTZGT 2000-10-01 09:30:00   26.0   NaN    NaN  12.428571    NaN
# 0  DANTZGT 2002-10-01 09:30:00    NaN  10.0  15.17        NaN  31.18
# 0  DANTZGT 2003-10-01 07:11:00   89.0   5.0  13.25   5.821429  33.03
# 0  DANTZGT 2009-10-01 10:19:00    NaN   NaN   15.0        NaN   31.4
# 0  DANTZGT 2010-10-01 08:02:00  160.0   3.0   12.4  18.928571   28.9
#
#         PO4    pH       NO3       NO2        NH4        E CHLFa      TIJD  \
# 0  1.483871   NaN  1.142857       1.0        9.5      NaN   8.0  09:30:00
# 0       NaN  8.06       NaN       NaN        NaN      NaN   NaN  09:30:00
# 0  1.354839  8.13  1.214286  0.714286   9.142857  3.23678  20.6  07:11:00
# 0       NaN   NaN       NaN       NaN        NaN      NaN   NaN  10:19:00
# 0  0.806452   8.0  3.571429  1.642857  15.714286     4.61  16.0  08:02:00
#
#         DATUM
# 0  2000-10-01
# 0  2002-10-01
# 0  2003-10-01
# 0  2009-10-01
# 0  2010-10-01

# %%
# abio_flattened = abio_flattened.drop('DATUMTIJDWAARDE', axis=1)
new_order = ['LOC_CODE', 'DATUM', 'TIJD'] + unique_VARS + ['DATUMTIJDWAARDE']

abio_flattened = abio_flattened[new_order]
abio_flattened.head()
# Out:
#   LOC_CODE       DATUM      TIJD     ZS ZICHT      T       SiO2 SALNTT  \
# 0  DANTZGT  2000-10-01  09:30:00   26.0   NaN    NaN  12.428571    NaN
# 0  DANTZGT  2002-10-01  09:30:00    NaN  10.0  15.17        NaN  31.18
# 0  DANTZGT  2003-10-01  07:11:00   89.0   5.0  13.25   5.821429  33.03
# 0  DANTZGT  2009-10-01  10:19:00    NaN   NaN   15.0        NaN   31.4
# 0  DANTZGT  2010-10-01  08:02:00  160.0   3.0   12.4  18.928571   28.9
#
#         PO4    pH       NO3       NO2        NH4        E CHLFa  \
# 0  1.483871   NaN  1.142857       1.0        9.5      NaN   8.0
# 0       NaN  8.06       NaN       NaN        NaN      NaN   NaN
# 0  1.354839  8.13  1.214286  0.714286   9.142857  3.23678  20.6
# 0       NaN   NaN       NaN       NaN        NaN      NaN   NaN
# 0  0.806452   8.0  3.571429  1.642857  15.714286     4.61  16.0
#
#       DATUMTIJDWAARDE
# 0 2000-10-01 09:30:00
# 0 2002-10-01 09:30:00
# 0 2003-10-01 07:11:00
# 0 2009-10-01 10:19:00
# 0 2010-10-01 08:02:00

# %% [markdown]
# #### Append the units to the variable columns

# %%
var_unit_dict = {}
for var in unique_VARS:
    var_df = abio_df.loc[abio_df["VAR"] == var]
    first_row = var_df.iloc[0]
    unit = first_row['EHD']
    var_unit_dict[var] = str(var) + f" [{unit}]"

# %%
abio_flattened = abio_flattened.rename(columns=var_unit_dict)

# %% [markdown]
# #### Combine multiple measurements on a day to one per day

# %%
abio_unconflicting = abio_flattened

duplicates = abio_unconflicting[abio_unconflicting.duplicated(subset=['DATUM', 'LOC_CODE'], keep=False)].sort_values('DATUM')

no_duplicates = abio_unconflicting[~abio_unconflicting.duplicated(subset=['DATUM', 'LOC_CODE'], keep=False)].drop("DATUMTIJDWAARDE", axis=1)

display(duplicates.info())
display(no_duplicates.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3073 entries, 0 to 0
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LOC_CODE         3073 non-null   object
#  1   DATUM            3073 non-null   object
#  2   TIJD             3073 non-null   object
#  3   ZS [mg/l]        1726 non-null   object
#  4   ZICHT [dm]       205 non-null    object
#  5   T [oC]           1400 non-null   object
#  6   SiO2 [umol/L]    1279 non-null   object
#  7   SALNTT [DIMSLS]  1377 non-null   object
#  8   PO4 [umol/L]     1269 non-null   object
#  9   pH [DIMSLS]      1374 non-null   object
#  10  NO3 [umol/L]     1243 non-null   object
#  11  NO2 [umol/L]     1265 non-null   object
#  12  NH4 [umol/L]     1268 non-null   object
#  13  E [/m]           972 non-null    object
#  14  CHLFa [ug/l]     1411 non-null   object
#  15  DATUMTIJDWAARDE  3073 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(15)
# memory usage: 408.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 12220 entries, 0 to 0
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LOC_CODE         12220 non-null  object
#  1   DATUM            12220 non-null  object
#  2   TIJD             12220 non-null  object
#  3   ZS [mg/l]        11450 non-null  object
#  4   ZICHT [dm]       5708 non-null   object
#  5   T [oC]           11309 non-null  object
#  6   SiO2 [umol/L]    11353 non-null  object
#  7   SALNTT [DIMSLS]  10676 non-null  object
#  8   PO4 [umol/L]     11384 non-null  object
#  9   pH [DIMSLS]      11086 non-null  object
#  10  NO3 [umol/L]     11048 non-null  object
#  11  NO2 [umol/L]     11396 non-null  object
#  12  NH4 [umol/L]     11369 non-null  object
#  13  E [/m]           3982 non-null   object
#  14  CHLFa [ug/l]     11180 non-null  object
# dtypes: object(15)
# memory usage: 1.5+ MB
# None

# %% [markdown]
# #### Duplicates

# %% [markdown]
# #### Delete duplicate values if conflicting

# %%
NAN_THRESHOLD = 5 # max nan values if conflict exists
COLS_START = 3

# %%
grouped = duplicates.copy()

def check_conflicts(group):
    """
    Returns string that indicates the type of conflicting
    measurement on the same day.
    
    """
    conflicting_columns = []
    for column in group.columns[COLS_START:-1]:
        non_nan_count = group[column].notna().sum()
        if non_nan_count > 1:
            conflicting_columns.append(column)
    return ', '.join(conflicting_columns)


# adds a 'conflicts' column to grouped
conflicts = grouped.groupby(['LOC_CODE', 'DATUM']).apply(check_conflicts).reset_index(name='Conflicts')
grouped = pd.merge(grouped, conflicts, on=['LOC_CODE', 'DATUM'], how='left')
# Out:
# C:\Users\Ardjano Mark\AppData\Local\Temp\ipykernel_5016\2454798714.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   conflicts = grouped.groupby(['LOC_CODE', 'DATUM']).apply(check_conflicts).reset_index(name='Conflicts')

# %%
mask_nan = grouped.isnull().sum(axis=1) > NAN_THRESHOLD 
mask_conflicts = grouped["Conflicts"] != ''

fixed_conflicts = grouped[~(mask_nan & mask_conflicts)].reset_index(drop=True)

# %%
# check for what's being filtered out; reverse filter_within_time > -> < for it to work
# filtered = duplicates2.groupby(['LOC_CODE', 'DATUM']).apply(lambda group: filter_within_time(group, minutes=120)).reset_index(drop=True)

# display(filtered)

# result = pd.merge(duplicates2, filtered[['LOC_CODE', 'DATUM']], on=['LOC_CODE', 'DATUM'], how='inner')

# display(result[57:])

# %% [markdown]
# #### Retains only values withing timeframe

# %%
TIMEFRAME = 120 # minutes

# %%
def main_measurement(group):
    """Finds row with least null values."""
    return group.isnull().sum(axis=1).idxmin()

def filter_within_time(group, minutes):
    """
    Finds all measurements that fall within the defined time range,
    relative to the main measurement.
    
    """
    seconds = 60 * minutes
    main_idx = main_measurement(group)
    main_time = group.loc[main_idx, 'DATUMTIJDWAARDE']

    delta_time = (group['DATUMTIJDWAARDE'] - main_time).dt.total_seconds().abs()
    # reverse this to check how many will be eliminated
    is_in_time = delta_time < seconds

    return group[is_in_time]

filtered = fixed_conflicts.groupby(['LOC_CODE', 'DATUM']).apply(lambda group: filter_within_time(group, minutes=TIMEFRAME)).reset_index(drop=True).sort_values('DATUM')

# display(filtered)
# Out:
# C:\Users\Ardjano Mark\AppData\Local\Temp\ipykernel_5016\2328798680.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   filtered = fixed_conflicts.groupby(['LOC_CODE', 'DATUM']).apply(lambda group: filter_within_time(group, minutes=TIMEFRAME)).reset_index(drop=True).sort_values('DATUM')

# %% [markdown]
# #### Combining duplicate abiotic values

# %%
filtered_notime = filtered.drop(['DATUMTIJDWAARDE', 'TIJD', 'Conflicts'], axis=1).reset_index(drop=True)
n_groups = filtered_notime.groupby(["LOC_CODE", "DATUM"]).ngroups

# %%
combined_duplicates = filtered_notime.groupby(["LOC_CODE", "DATUM"], as_index=False).first()

for col in combined_duplicates.columns:
    if combined_duplicates[col].dtype == 'object':
            combined_duplicates[col] = combined_duplicates[col].replace({None: np.nan})

assert n_groups == combined_duplicates.shape[0], "Doesn't match" # sanity check

display(combined_duplicates)
# Out:
# C:\Users\Ardjano Mark\AppData\Local\Temp\ipykernel_5016\2636423642.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_duplicates[col] = combined_duplicates[col].replace({None: np.nan})
#       LOC_CODE       DATUM  ZS [mg/l]  ZICHT [dm]  T [oC]  SiO2 [umol/L]  \
# 0      DANTZGT  1994-03-29       74.0         2.0    7.90      19.571429
# 1      DANTZGT  1994-06-09       47.0         6.0   15.00       4.535714
# 2      DANTZGT  1994-08-22       64.0         5.0   18.50       3.000000
# 3      DANTZGT  1994-11-17      135.0         3.0    9.30      14.500000
# 4      DANTZGT  1995-02-14      139.0         3.0    6.00      54.285714
# ...        ...         ...        ...         ...     ...            ...
# 1280  WALCRN70  2006-08-07        2.0         NaN     NaN       0.428571
# 1281  WALCRN70  2006-09-14        3.2         NaN     NaN       0.500000
# 1282  WALCRN70  2006-10-11        4.7         NaN   17.41       1.785714
# 1283  WALCRN70  2006-11-15        3.4         NaN     NaN       1.500000
# 1284  WALCRN70  2006-12-20        4.3         NaN     NaN       4.535714
#
#       SALNTT [DIMSLS]  PO4 [umol/L]  pH [DIMSLS]  NO3 [umol/L]  NO2 [umol/L]  \
# 0               27.03      0.548387        8.000     63.928571      1.357143
# 1               27.25      0.483871        8.100      6.214286      1.142857
# 2               32.74      1.741935        8.100      0.714286      1.500000
# 3               19.05      0.967742        8.100     16.714286      3.000000
# 4               18.72      1.290323        7.900    119.285714      3.428571
# ...               ...           ...          ...           ...           ...
# 1280              NaN      0.064516          NaN      0.107143      0.035714
# 1281              NaN      0.129032          NaN      0.107143      0.035714
# 1282            35.08      0.129032        7.996      0.107143      0.035714
# 1283              NaN      0.258065          NaN      0.714286      0.035714
# 1284              NaN      0.451613          NaN      7.071429      0.142857
#
#       NH4 [umol/L]  E [/m]  CHLFa [ug/l]
# 0         2.071429     NaN         27.20
# 1        10.071429     NaN         24.20
# 2        13.071429     NaN         29.00
# 3        16.357143     NaN         11.30
# 4         9.000000     NaN         11.50
# ...            ...     ...           ...
# 1280      0.071429     NaN          1.08
# 1281      0.071429     NaN          2.24
# 1282      0.071429     NaN          2.14
# 1283      0.714286     NaN          1.58
# 1284      0.071429     NaN          0.58
#
# [1285 rows x 14 columns]

# %% [markdown]
# #### Final merge with rest of data

# %%
final_abio = pd.concat([no_duplicates, combined_duplicates]).sort_values(by=["LOC_CODE", "DATUM"])

display(final_abio)
# Out:
#     LOC_CODE       DATUM      TIJD ZS [mg/l] ZICHT [dm] T [oC] SiO2 [umol/L]  \
# 0    DANTZGT  1990-01-10  15:00:00     135.0        2.0    4.0     20.178571
# 0    DANTZGT  1990-02-06  13:40:00     295.0        0.5    6.0           NaN
# 0    DANTZGT  1990-03-08  13:45:00     103.0        3.0    7.3     19.428571
# 0    DANTZGT  1990-04-04  10:00:00     113.0        3.0    8.2      6.285714
# 0    DANTZGT  1990-05-09  15:30:00      20.0       11.0   17.4      1.714286
# ..       ...         ...       ...       ...        ...    ...           ...
# 0   WALCRN70  2020-08-13  05:04:00      4.02        NaN   18.5      0.632143
# 0   WALCRN70  2020-09-16  09:30:00      4.52        NaN   18.5         1.275
# 0   WALCRN70  2020-10-14  08:25:00      4.99        NaN   15.7      1.682143
# 0   WALCRN70  2020-11-17  05:58:00      3.92        NaN   13.9      3.607143
# 0   WALCRN70  2020-12-16  10:04:00      6.06        NaN   11.6      3.510714
#
#    SALNTT [DIMSLS] PO4 [umol/L] pH [DIMSLS] NO3 [umol/L] NO2 [umol/L]  \
# 0            29.19     1.645161         7.8    37.571429     3.714286
# 0            27.37          NaN         NaN          NaN          NaN
# 0            24.99     0.709677         8.0    89.285714     2.071429
# 0            28.79     0.806452         8.1         40.0          2.0
# 0            33.28      1.16129         8.3     0.214286     0.142857
# ..             ...          ...         ...          ...          ...
# 0             35.0     0.577419         8.0     0.357143     0.035714
# 0             34.8     0.190323        7.97     2.278571     0.114286
# 0             34.9     0.206452        8.11     0.357143     0.242857
# 0             35.0      0.43871        8.13     6.442857     0.842857
# 0             35.0      0.43871        7.89     8.785714     0.164286
#
#    NH4 [umol/L] E [/m] CHLFa [ug/l]
# 0     14.071429    NaN          1.3
# 0           NaN    NaN          NaN
# 0      8.642857    NaN         21.1
# 0      6.428571    NaN         25.0
# 0      1.928571    NaN         10.2
# ..          ...    ...          ...
# 0      0.178571    NaN         0.77
# 0      0.485714   0.12         1.47
# 0      0.364286    NaN         2.02
# 0      0.178571    NaN         1.59
# 0      0.178571    NaN         0.83
#
# [13505 rows x 15 columns]

# %% [markdown]
# ### Prepare phytoplankton data

# %%
# rename the date_smp column
phyto_df['DATE_SMP'] = pd.to_datetime(phyto_df['DATE_SMP'].dt.date)
phyto_df.rename(columns={'DATE_SMP':'DATUM'}, inplace=True)

display(phyto_df)
# Out:
#             LOC_CODE  LOC      WATERBODY       TYPE      DATUM  YEAR  MONTH  \
# 0           GROOTGND  EDG    EEMSDOLLARD  ESTUARINE 2005-01-21   NaN    NaN
# 1           GROOTGND  EDG    EEMSDOLLARD  ESTUARINE 1994-01-25   NaN    NaN
# 2           GROOTGND  EDG    EEMSDOLLARD  ESTUARINE 1994-02-24   NaN    NaN
# 3           GROOTGND  EDG    EEMSDOLLARD  ESTUARINE 2001-03-22   NaN    NaN
# 4           GROOTGND  EDG    EEMSDOLLARD  ESTUARINE 2002-03-13   NaN    NaN
# ...              ...  ...            ...        ...        ...   ...    ...
# 105277       HANSWGL  WSH  WESTERSCHELDE  ESTUARINE 1994-11-22   NaN    NaN
# 105278  VLISSGBISSVH  WSV  WESTERSCHELDE  ESTUARINE 1994-11-22   NaN    NaN
# 105279       HANSWGL  WSH  WESTERSCHELDE  ESTUARINE 2000-12-19   NaN    NaN
# 105280  VLISSGBISSVH  WSV  WESTERSCHELDE  ESTUARINE 2006-12-12   NaN    NaN
# 105281   SCHAARVODDL  WSO  WESTERSCHELDE  ESTUARINE 2011-12-05   NaN    NaN
#
#         DAY  Q_clndr  Q_eco PROD_CODE                SPECIES SPEC GROUP  \
# 0       NaN      NaN      1        OW  Actinocyclus normanii  Acn  DIAT
# 1       NaN      NaN      1    WATSGL  Actinocyclus normanii  Acn  DIAT
# 2       NaN      NaN      1    WATSGL  Actinocyclus normanii  Acn  DIAT
# 3       NaN      NaN      2        OW  Actinocyclus normanii  Acn  DIAT
# 4       NaN      NaN      2        OW  Actinocyclus normanii  Acn  DIAT
# ...     ...      ...    ...       ...                    ...  ...   ...
# 105277  NaN      NaN      4    WATSGL    Torodinium robustum  Tor  DINO
# 105278  NaN      NaN      4    WATSGL    Torodinium robustum  Tor  DINO
# 105279  NaN      NaN      1        OW    Torodinium robustum  Tor  DINO
# 105280  NaN      NaN      1        OW    Torodinium robustum  Tor  DINO
# 105281  NaN      NaN      1        OW    Torodinium robustum  Tor  DINO
#
#         AMT_MEAS           cL  LcL
# 0            1.0  5000.000000  NaN
# 1            NaN  2000.000000  NaN
# 2            NaN   485.000000  NaN
# 3            1.0   833.333333  NaN
# 4            2.0  4000.000000  NaN
# ...          ...          ...  ...
# 105277       NaN   127.000000  NaN
# 105278       NaN   150.000000  NaN
# 105279       1.0  1000.000000  NaN
# 105280       1.0   769.000000  NaN
# 105281       1.0   285.714286  NaN
#
# [105282 rows x 17 columns]

# %% [markdown]
# #### Handle duplicates

# %%
# Rhizosolenia delicatula with Guinardia
phyto_df["SPEC"] = phyto_df["SPEC"].replace({"Rde": "Gde" })

# %%
# Check that everything went right
spec_to_species_df = phyto_df.groupby('SPEC')['SPECIES'].unique().reset_index()
spec_to_species_df.columns = ['Abrv','Species']

# display_all(spec_to_species_df)

phyto_duplicates = spec_to_species_df[spec_to_species_df['Species'].apply(len) > 1]
print(phyto_duplicates)
# Out:
#    Abrv                                            Species
# 2   Agl  [Asterionella glacialis, Asterionellopsis glac...
# 13  Cha                 [Chattonella, Chattonella antiqua]
# 31  Gde    [Guinardia delicatula, Rhizosolenia delicatula]

# %%
# conflict between species/group after merge, keep only relevant columns
phyto_df.drop([col for col in phyto_df.columns if col not in ["LOC_CODE", "SPEC", "DATUM", "cL"]], axis=1, inplace=True)

display(phyto_df)
# Out:
#             LOC_CODE      DATUM SPEC           cL
# 0           GROOTGND 2005-01-21  Acn  5000.000000
# 1           GROOTGND 1994-01-25  Acn  2000.000000
# 2           GROOTGND 1994-02-24  Acn   485.000000
# 3           GROOTGND 2001-03-22  Acn   833.333333
# 4           GROOTGND 2002-03-13  Acn  4000.000000
# ...              ...        ...  ...          ...
# 105277       HANSWGL 1994-11-22  Tor   127.000000
# 105278  VLISSGBISSVH 1994-11-22  Tor   150.000000
# 105279       HANSWGL 2000-12-19  Tor  1000.000000
# 105280  VLISSGBISSVH 2006-12-12  Tor   769.000000
# 105281   SCHAARVODDL 2011-12-05  Tor   285.714286
#
# [105282 rows x 4 columns]

# %% [markdown]
# #### Aggregating measurements on same day

# %%
phyto_duplicates = phyto_df[phyto_df.duplicated(subset=["LOC_CODE", "DATUM", "SPEC"], keep=False)].sort_values(by=["LOC_CODE", "DATUM", "SPEC"]).reset_index(drop=True)
phyto_non_duplicates = phyto_df[~phyto_df.duplicated(subset=["LOC_CODE", "DATUM", "SPEC"], keep=False)]

display(phyto_duplicates)
# display(phyto_non_duplicates)

n_duplicates = len(phyto_duplicates.groupby(["LOC_CODE", "DATUM", "SPEC"]).size())
display(n_duplicates)
# Out:
#       LOC_CODE      DATUM SPEC             cL
# 0      DANTZGT 2000-02-15  Oau    5000.000000
# 1      DANTZGT 2000-02-15  Oau    5000.000000
# 2      DANTZGT 2000-03-28  Oau  135000.000000
# 3      DANTZGT 2000-03-28  Oau    4000.000000
# 4      DANTZGT 2000-05-29  Oau   62500.000000
# ...        ...        ...  ...            ...
# 5067  WALCRN70 2019-07-15  Pha   14937.927834
# 5068  WALCRN70 2019-08-15  Rse    1111.111111
# 5069  WALCRN70 2019-08-15  Rse     707.070707
# 5070  WALCRN70 2019-09-12  Pha   39543.651986
# 5071  WALCRN70 2019-09-12  Pha    4393.739110
#
# [5072 rows x 4 columns]
# 2355

# %%
# distinct_counts = phyto_duplicates.groupby(['LOC_CODE', 'DATUM', 'SPEC']).agg(lambda x: x.nunique())
# display(distinct_counts)

# %%
display(phyto_duplicates['SPEC'].value_counts())
# Out:
# SPEC
# Pha    4466
# Oau     310
# Rse     290
# Gsp       2
# Kgl       2
# Tor       2
# Name: count, dtype: int64

# %%
def spec_aggregate(group):
    if any(spec in group["SPEC"].values for spec in ["Agl", "Cha", "Oau", "Pha", "Gde"]):
        return group['cL'].sum()
    else:
        return group['cL'].mean()

phyto_aggregated = phyto_duplicates.groupby(["LOC_CODE", "DATUM", "SPEC"]).apply(spec_aggregate).reset_index(name='cL')

display(phyto_aggregated)
# Out:
# C:\Users\Ardjano Mark\AppData\Local\Temp\ipykernel_5016\3386604244.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   phyto_aggregated = phyto_duplicates.groupby(["LOC_CODE", "DATUM", "SPEC"]).apply(spec_aggregate).reset_index(name='cL')
#       LOC_CODE      DATUM SPEC            cL
# 0      DANTZGT 2000-02-15  Oau  1.000000e+04
# 1      DANTZGT 2000-03-28  Oau  1.390000e+05
# 2      DANTZGT 2000-05-29  Oau  9.375000e+04
# 3      DANTZGT 2000-05-29  Pha  4.103343e+07
# 4      DANTZGT 2000-06-09  Pha  1.971079e+06
# ...        ...        ...  ...           ...
# 2350  WALCRN70 2019-05-16  Pha  1.581818e+07
# 2351  WALCRN70 2019-06-13  Pha  9.864151e+04
# 2352  WALCRN70 2019-07-15  Pha  7.842412e+04
# 2353  WALCRN70 2019-08-15  Rse  9.090909e+02
# 2354  WALCRN70 2019-09-12  Pha  4.393739e+04
#
# [2355 rows x 4 columns]

# %%
final_phyto = pd.concat([phyto_non_duplicates, phyto_aggregated]).sort_values(by=["LOC_CODE", "DATUM", "SPEC"]).reset_index(drop=True)


display(final_phyto)
# Out:
#         LOC_CODE      DATUM SPEC            cL
# 0        DANTZGT 1990-04-04  Agl   1869.000000
# 1        DANTZGT 1990-04-04  Dbr  56075.000000
# 2        DANTZGT 1990-04-04  Ezo   3738.000000
# 3        DANTZGT 1990-04-04  Gde   3738.000000
# 4        DANTZGT 1990-04-04  Oau  20561.000000
# ...          ...        ...  ...           ...
# 102560  WALCRN70 2019-10-30  Kgl   5123.014487
# 102561  WALCRN70 2019-10-30  Nsi    102.021174
# 102562  WALCRN70 2019-10-30  Tni    714.148219
# 102563  WALCRN70 2019-10-30  Tor   8050.451336
# 102564  WALCRN70 2019-10-30  Tro    408.084697
#
# [102565 rows x 4 columns]

# %% [markdown]
# ### Use function from_df_to_row_df() from before to flatten the dataset based on Abbreviations.

# %%
# recompute 'LcL' column
final_phyto['LcL'] = np.log10(final_phyto['cL'] + 1)

# Extract unique species
unique_SPEC = final_phyto['SPEC'].unique()

# Group the DataFrame by 'LOC_CODE' and 'DATUM'
new_col_list = ["LOC_CODE", "DATUM"] + list(unique_SPEC)
phyto_flattened = pd.DataFrame(columns=new_col_list)

phyto_grouped = final_phyto.groupby(['LOC_CODE', 'DATUM'])

# Iterate over the groups
for (location, time), group_df in phyto_grouped:
    # 'location' and 'time' are the current group keys
    # 'group_df' is the DataFrame for the current group
    # Process the group_df as needed
    # print(group_df)
    group = from_df_to_row_df(group_df, location, time, col_list=["LOC_CODE", "DATUM", 'SPEC', "LcL"])
    phyto_flattened = pd.concat([phyto_flattened, group], axis=0, join='outer')
     
phyto_flattened.head()
# Out:
#   LOC_CODE                DATUM       Agl       Dbr       Ezo       Gde  \
# 0  DANTZGT  1990-04-04 00:00:00  3.271842  4.748777  3.572755  3.572755
# 0  DANTZGT  1990-04-24 00:00:00  4.590418  4.669596  3.447933  5.170191
# 0  DANTZGT  1990-05-09 00:00:00  4.669596       NaN  3.271842  3.970672
# 0  DANTZGT  1990-05-23 00:00:00       NaN  1.991226       NaN  4.067889
# 0  DANTZGT  1990-06-07 00:00:00  5.300487  1.968483       NaN  3.307282
#
#         Oau       Omo       Orh       Osi       Ram       Rse       Tec  \
# 0  4.313065  3.748808  3.572755  3.873785  3.271842  3.271842  3.572755
# 0       NaN  3.669689  2.670246  2.574031  1.973128  4.192484       NaN
# 0       NaN  2.670246  1.973128       NaN       NaN  5.192467       NaN
# 0  2.292256  2.292256       NaN  2.466868       NaN  2.989005       NaN
# 0       NaN  2.664642  1.968483       NaN       NaN   4.88552  1.968483
#
#         Tle       Tni       Tro       Dle       Etr       Gfl       Gsp  \
# 0  3.572755  4.669596  4.475787       NaN       NaN       NaN       NaN
# 0       NaN  3.447933  3.447933  1.973128  2.670246  2.274158  2.670246
# 0       NaN       NaN  4.012035       NaN       NaN       NaN  3.669689
# 0       NaN       NaN  3.590842  3.289812       NaN       NaN  4.480036
# 0  3.442009  3.566909  3.496376   2.74351  3.265996       NaN  1.968483
#
#         Nsc       Pbi       Pbr       Pha       Stu       Kgl       Oro  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.670246  4.192484  2.670246  3.891482  2.448706       NaN       NaN
# 0  3.271842  3.669689       NaN       NaN       NaN  1.973128  2.816241
# 0       NaN  3.289812       NaN       NaN       NaN       NaN  3.289812
# 0  2.444045       NaN  1.968483   5.73061       NaN       NaN  4.078674
#
#         Tor       Cdi       Cra       Ore       Ata       Cfu       Cgr  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0  1.973128       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  3.590842  1.991226  2.767898       NaN       NaN       NaN
# 0  1.968483       NaN       NaN       NaN  2.267172  2.444045  2.568202
#
#         Lan       Pcl       Pmi       Pos       Pse Cden  Aco  Dip  Csu  Mnu  \
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0  4.456062  2.267172  1.968483  2.267172  3.442009  NaN  NaN  NaN  NaN  NaN
#
#    Pco Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  Gfa  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  Mpe  Pde  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# Extract date and time
# phyto_flattened['DATUMTIJDWAARDE'] = pd.to_datetime(phyto_flattened['DATUMTIJDWAARDE'])

# phyto_flattened['DATUM'] = phyto_flattened['DATUMTIJDWAARDE'].dt.date
# phyto_flattened['TIJD'] = phyto_flattened['DATUMTIJDWAARDE'].dt.time

# %%
# drop 'datumtijdwaarde'

# phyto_flattened = phyto_flattened.drop('DATUMTIJDWAARDE', axis=1)

# %%
display(phyto_flattened)
# Out:
#     LOC_CODE                DATUM       Agl       Dbr       Ezo       Gde  \
# 0    DANTZGT  1990-04-04 00:00:00  3.271842  4.748777  3.572755  3.572755
# 0    DANTZGT  1990-04-24 00:00:00  4.590418  4.669596  3.447933  5.170191
# 0    DANTZGT  1990-05-09 00:00:00  4.669596       NaN  3.271842  3.970672
# 0    DANTZGT  1990-05-23 00:00:00       NaN  1.991226       NaN  4.067889
# 0    DANTZGT  1990-06-07 00:00:00  5.300487  1.968483       NaN  3.307282
# ..       ...                  ...       ...       ...       ...       ...
# 0   WALCRN70  2019-06-13 00:00:00  2.333737       NaN       NaN       NaN
# 0   WALCRN70  2019-07-15 00:00:00       NaN       NaN       NaN  2.852508
# 0   WALCRN70  2019-08-15 00:00:00       NaN       NaN       NaN  4.462177
# 0   WALCRN70  2019-09-12 00:00:00       NaN       NaN       NaN  3.974579
# 0   WALCRN70  2019-10-30 00:00:00  2.708511       NaN   2.78755  3.864487
#
#          Oau       Omo       Orh       Osi       Ram       Rse       Tec  \
# 0   4.313065  3.748808  3.572755  3.873785  3.271842  3.271842  3.572755
# 0        NaN  3.669689  2.670246  2.574031  1.973128  4.192484       NaN
# 0        NaN  2.670246  1.973128       NaN       NaN  5.192467       NaN
# 0   2.292256  2.292256       NaN  2.466868       NaN  2.989005       NaN
# 0        NaN  2.664642  1.968483       NaN       NaN   4.88552  1.968483
# ..       ...       ...       ...       ...       ...       ...       ...
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  2.959085       NaN
# 0        NaN       NaN       NaN       NaN       NaN  2.081022       NaN
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#          Tle       Tni       Tro       Dle       Etr       Gfl       Gsp  \
# 0   3.572755  4.669596  4.475787       NaN       NaN       NaN       NaN
# 0        NaN  3.447933  3.447933  1.973128  2.670246  2.274158  2.670246
# 0        NaN       NaN  4.012035       NaN       NaN       NaN  3.669689
# 0        NaN       NaN  3.590842  3.289812       NaN       NaN  4.480036
# 0   3.442009  3.566909  3.496376   2.74351  3.265996       NaN  1.968483
# ..       ...       ...       ...       ...       ...       ...       ...
# 0        NaN  2.809514       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN   3.63015  2.309962
# 0        NaN  2.959085       NaN       NaN       NaN  3.004795       NaN
# 0        NaN  2.380246       NaN       NaN       NaN       NaN  2.081022
# 0        NaN  2.854396  2.611813       NaN       NaN  2.311844       NaN
#
#          Nsc       Pbi       Pbr       Pha       Stu       Kgl       Oro  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0   2.670246  4.192484  2.670246  3.891482  2.448706       NaN       NaN
# 0   3.271842  3.669689       NaN       NaN       NaN  1.973128  2.816241
# 0        NaN  3.289812       NaN       NaN       NaN       NaN  3.289812
# 0   2.444045       NaN  1.968483   5.73061       NaN       NaN  4.078674
# ..       ...       ...       ...       ...       ...       ...       ...
# 0        NaN       NaN       NaN  4.994064       NaN  3.031093       NaN
# 0        NaN       NaN       NaN  4.894455       NaN  3.765701       NaN
# 0        NaN  2.008643       NaN  4.967741       NaN  3.283345       NaN
# 0        NaN  2.081022       NaN  4.642844       NaN  3.156887       NaN
# 0        NaN       NaN       NaN       NaN       NaN   3.70961       NaN
#
#          Tor       Cdi       Cra       Ore       Ata       Cfu       Cgr  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0   1.973128       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN  3.590842  1.991226  2.767898       NaN       NaN       NaN
# 0   1.968483       NaN       NaN       NaN  2.267172  2.444045  2.568202
# ..       ...       ...       ...       ...       ...       ...       ...
# 0   2.333737       NaN       NaN       NaN       NaN       NaN       NaN
# 0   2.961517       NaN       NaN       NaN       NaN       NaN       NaN
# 0   3.004795       NaN       NaN       NaN       NaN       NaN       NaN
# 0    3.28175       NaN       NaN       NaN       NaN       NaN       NaN
# 0   3.905874       NaN  2.487228       NaN       NaN       NaN       NaN
#
#          Lan       Pcl       Pmi       Pos       Pse Cden       Aco       Dip  \
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0   4.456062  2.267172  1.968483  2.267172  3.442009  NaN       NaN       NaN
# ..       ...       ...       ...       ...       ...  ...       ...       ...
# 0        NaN       NaN       NaN       NaN       NaN  NaN  2.034717       NaN
# 0        NaN       NaN  2.011054  2.011054       NaN  NaN       NaN       NaN
# 0        NaN       NaN  2.008643       NaN  4.046956  NaN  2.008643  2.607498
# 0        NaN       NaN       NaN       NaN  3.535327  NaN       NaN  2.380246
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN  2.708511
#
#     Csu  Mnu  Pco      Cdeb  Cwa  Pba  Dac       Ptr  Lun       Nsi  Rst  Pst  \
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# ..  ...  ...  ...       ...  ...  ...  ...       ...  ...       ...  ...  ...
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN  2.008643  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN  2.980947  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  2.012926  NaN  NaN
#
#     Acn  Tno       Ccu  Pan  Gfa  Hta       Dsp  Psu  Cei       Ndi       Cda  \
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# ..  ...  ...       ...  ...  ...  ...       ...  ...  ...       ...       ...
# 0   NaN  NaN       NaN  NaN  NaN  NaN  2.034717  NaN  NaN  2.034717       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN  2.482917       NaN
# 0   NaN  NaN  2.980947  NaN  NaN  NaN       NaN  NaN  NaN       NaN  3.032049
# 0   NaN  NaN       NaN  NaN  NaN  NaN  3.943658  NaN  NaN       NaN       NaN
#
#     Dro  Cha  Pac  Cau  Coc  Pte  Edu       Mpe  Pde  Plo  Dpu  Rte  Fja  Hak  \
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..  ...  ...  ...  ...  ...  ...  ...       ...  ...  ...  ...  ...  ...  ...
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.863132  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.081022  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     Mhe  Dno  Dat
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# ..  ...  ...  ...
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
#
# [11063 rows x 82 columns]

# %%
# check for duplicates
dups = phyto_flattened[phyto_flattened[['LOC_CODE','DATUM']].duplicated(keep=False)]
display(dups)
# Out:
# Empty DataFrame
# Columns: [LOC_CODE, DATUM, Agl, Dbr, Ezo, Gde, Oau, Omo, Orh, Osi, Ram, Rse, Tec, Tle, Tni, Tro, Dle, Etr, Gfl, Gsp, Nsc, Pbi, Pbr, Pha, Stu, Kgl, Oro, Tor, Cdi, Cra, Ore, Ata, Cfu, Cgr, Lan, Pcl, Pmi, Pos, Pse, Cden, Aco, Dip, Csu, Mnu, Pco, Cdeb, Cwa, Pba, Dac, Ptr, Lun, Nsi, Rst, Pst, Acn, Tno, Ccu, Pan, Gfa, Hta, Dsp, Psu, Cei, Ndi, Cda, Dro, Cha, Pac, Cau, Coc, Pte, Edu, Mpe, Pde, Plo, Dpu, Rte, Fja, Hak, Mhe, Dno, Dat]
# Index: []

# %%
# reorder phyto_flattened columns

new_order = ['LOC_CODE', 'DATUM'] + list(unique_SPEC)

phyto_flattened = phyto_flattened[new_order]
phyto_flattened.head()
# Out:
#   LOC_CODE                DATUM       Agl       Dbr       Ezo       Gde  \
# 0  DANTZGT  1990-04-04 00:00:00  3.271842  4.748777  3.572755  3.572755
# 0  DANTZGT  1990-04-24 00:00:00  4.590418  4.669596  3.447933  5.170191
# 0  DANTZGT  1990-05-09 00:00:00  4.669596       NaN  3.271842  3.970672
# 0  DANTZGT  1990-05-23 00:00:00       NaN  1.991226       NaN  4.067889
# 0  DANTZGT  1990-06-07 00:00:00  5.300487  1.968483       NaN  3.307282
#
#         Oau       Omo       Orh       Osi       Ram       Rse       Tec  \
# 0  4.313065  3.748808  3.572755  3.873785  3.271842  3.271842  3.572755
# 0       NaN  3.669689  2.670246  2.574031  1.973128  4.192484       NaN
# 0       NaN  2.670246  1.973128       NaN       NaN  5.192467       NaN
# 0  2.292256  2.292256       NaN  2.466868       NaN  2.989005       NaN
# 0       NaN  2.664642  1.968483       NaN       NaN   4.88552  1.968483
#
#         Tle       Tni       Tro       Dle       Etr       Gfl       Gsp  \
# 0  3.572755  4.669596  4.475787       NaN       NaN       NaN       NaN
# 0       NaN  3.447933  3.447933  1.973128  2.670246  2.274158  2.670246
# 0       NaN       NaN  4.012035       NaN       NaN       NaN  3.669689
# 0       NaN       NaN  3.590842  3.289812       NaN       NaN  4.480036
# 0  3.442009  3.566909  3.496376   2.74351  3.265996       NaN  1.968483
#
#         Nsc       Pbi       Pbr       Pha       Stu       Kgl       Oro  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.670246  4.192484  2.670246  3.891482  2.448706       NaN       NaN
# 0  3.271842  3.669689       NaN       NaN       NaN  1.973128  2.816241
# 0       NaN  3.289812       NaN       NaN       NaN       NaN  3.289812
# 0  2.444045       NaN  1.968483   5.73061       NaN       NaN  4.078674
#
#         Tor       Cdi       Cra       Ore       Ata       Cfu       Cgr  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0  1.973128       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  3.590842  1.991226  2.767898       NaN       NaN       NaN
# 0  1.968483       NaN       NaN       NaN  2.267172  2.444045  2.568202
#
#         Lan       Pcl       Pmi       Pos       Pse Cden  Aco  Dip  Csu  Mnu  \
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0  4.456062  2.267172  1.968483  2.267172  3.442009  NaN  NaN  NaN  NaN  NaN
#
#    Pco Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  Gfa  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  Mpe  Pde  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# drop tijd
# phyto_flattened = phyto_flattened.drop(columns='TIJD', axis=1)

# %%
phyto_flattened
# Out:
#     LOC_CODE                DATUM       Agl       Dbr       Ezo       Gde  \
# 0    DANTZGT  1990-04-04 00:00:00  3.271842  4.748777  3.572755  3.572755
# 0    DANTZGT  1990-04-24 00:00:00  4.590418  4.669596  3.447933  5.170191
# 0    DANTZGT  1990-05-09 00:00:00  4.669596       NaN  3.271842  3.970672
# 0    DANTZGT  1990-05-23 00:00:00       NaN  1.991226       NaN  4.067889
# 0    DANTZGT  1990-06-07 00:00:00  5.300487  1.968483       NaN  3.307282
# ..       ...                  ...       ...       ...       ...       ...
# 0   WALCRN70  2019-06-13 00:00:00  2.333737       NaN       NaN       NaN
# 0   WALCRN70  2019-07-15 00:00:00       NaN       NaN       NaN  2.852508
# 0   WALCRN70  2019-08-15 00:00:00       NaN       NaN       NaN  4.462177
# 0   WALCRN70  2019-09-12 00:00:00       NaN       NaN       NaN  3.974579
# 0   WALCRN70  2019-10-30 00:00:00  2.708511       NaN   2.78755  3.864487
#
#          Oau       Omo       Orh       Osi       Ram       Rse       Tec  \
# 0   4.313065  3.748808  3.572755  3.873785  3.271842  3.271842  3.572755
# 0        NaN  3.669689  2.670246  2.574031  1.973128  4.192484       NaN
# 0        NaN  2.670246  1.973128       NaN       NaN  5.192467       NaN
# 0   2.292256  2.292256       NaN  2.466868       NaN  2.989005       NaN
# 0        NaN  2.664642  1.968483       NaN       NaN   4.88552  1.968483
# ..       ...       ...       ...       ...       ...       ...       ...
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  2.959085       NaN
# 0        NaN       NaN       NaN       NaN       NaN  2.081022       NaN
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#          Tle       Tni       Tro       Dle       Etr       Gfl       Gsp  \
# 0   3.572755  4.669596  4.475787       NaN       NaN       NaN       NaN
# 0        NaN  3.447933  3.447933  1.973128  2.670246  2.274158  2.670246
# 0        NaN       NaN  4.012035       NaN       NaN       NaN  3.669689
# 0        NaN       NaN  3.590842  3.289812       NaN       NaN  4.480036
# 0   3.442009  3.566909  3.496376   2.74351  3.265996       NaN  1.968483
# ..       ...       ...       ...       ...       ...       ...       ...
# 0        NaN  2.809514       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN   3.63015  2.309962
# 0        NaN  2.959085       NaN       NaN       NaN  3.004795       NaN
# 0        NaN  2.380246       NaN       NaN       NaN       NaN  2.081022
# 0        NaN  2.854396  2.611813       NaN       NaN  2.311844       NaN
#
#          Nsc       Pbi       Pbr       Pha       Stu       Kgl       Oro  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0   2.670246  4.192484  2.670246  3.891482  2.448706       NaN       NaN
# 0   3.271842  3.669689       NaN       NaN       NaN  1.973128  2.816241
# 0        NaN  3.289812       NaN       NaN       NaN       NaN  3.289812
# 0   2.444045       NaN  1.968483   5.73061       NaN       NaN  4.078674
# ..       ...       ...       ...       ...       ...       ...       ...
# 0        NaN       NaN       NaN  4.994064       NaN  3.031093       NaN
# 0        NaN       NaN       NaN  4.894455       NaN  3.765701       NaN
# 0        NaN  2.008643       NaN  4.967741       NaN  3.283345       NaN
# 0        NaN  2.081022       NaN  4.642844       NaN  3.156887       NaN
# 0        NaN       NaN       NaN       NaN       NaN   3.70961       NaN
#
#          Tor       Cdi       Cra       Ore       Ata       Cfu       Cgr  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0   1.973128       NaN       NaN       NaN       NaN       NaN       NaN
# 0        NaN  3.590842  1.991226  2.767898       NaN       NaN       NaN
# 0   1.968483       NaN       NaN       NaN  2.267172  2.444045  2.568202
# ..       ...       ...       ...       ...       ...       ...       ...
# 0   2.333737       NaN       NaN       NaN       NaN       NaN       NaN
# 0   2.961517       NaN       NaN       NaN       NaN       NaN       NaN
# 0   3.004795       NaN       NaN       NaN       NaN       NaN       NaN
# 0    3.28175       NaN       NaN       NaN       NaN       NaN       NaN
# 0   3.905874       NaN  2.487228       NaN       NaN       NaN       NaN
#
#          Lan       Pcl       Pmi       Pos       Pse Cden       Aco       Dip  \
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN       NaN
# 0   4.456062  2.267172  1.968483  2.267172  3.442009  NaN       NaN       NaN
# ..       ...       ...       ...       ...       ...  ...       ...       ...
# 0        NaN       NaN       NaN       NaN       NaN  NaN  2.034717       NaN
# 0        NaN       NaN  2.011054  2.011054       NaN  NaN       NaN       NaN
# 0        NaN       NaN  2.008643       NaN  4.046956  NaN  2.008643  2.607498
# 0        NaN       NaN       NaN       NaN  3.535327  NaN       NaN  2.380246
# 0        NaN       NaN       NaN       NaN       NaN  NaN       NaN  2.708511
#
#     Csu  Mnu  Pco      Cdeb  Cwa  Pba  Dac       Ptr  Lun       Nsi  Rst  Pst  \
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# ..  ...  ...  ...       ...  ...  ...  ...       ...  ...       ...  ...  ...
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN  2.008643  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN  2.980947  NaN  NaN  NaN       NaN  NaN       NaN  NaN  NaN
# 0   NaN  NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  2.012926  NaN  NaN
#
#     Acn  Tno       Ccu  Pan  Gfa  Hta       Dsp  Psu  Cei       Ndi       Cda  \
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# ..  ...  ...       ...  ...  ...  ...       ...  ...  ...       ...       ...
# 0   NaN  NaN       NaN  NaN  NaN  NaN  2.034717  NaN  NaN  2.034717       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN       NaN       NaN
# 0   NaN  NaN       NaN  NaN  NaN  NaN       NaN  NaN  NaN  2.482917       NaN
# 0   NaN  NaN  2.980947  NaN  NaN  NaN       NaN  NaN  NaN       NaN  3.032049
# 0   NaN  NaN       NaN  NaN  NaN  NaN  3.943658  NaN  NaN       NaN       NaN
#
#     Dro  Cha  Pac  Cau  Coc  Pte  Edu       Mpe  Pde  Plo  Dpu  Rte  Fja  Hak  \
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..  ...  ...  ...  ...  ...  ...  ...       ...  ...  ...  ...  ...  ...  ...
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.863132  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.081022  NaN  NaN  NaN  NaN  NaN  NaN
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     Mhe  Dno  Dat
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# ..  ...  ...  ...
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
# 0   NaN  NaN  NaN
#
# [11063 rows x 82 columns]

# %% [markdown]
# ### Prepare irradiance data

# %%
irradiance_df.head()
# Out:
#    YYYYMMDD      Q  YEAR  MONTH  PAR [J/m2d]  PAR [kJ/m2d]  kPAR_7d  kPAR_14d
# 0  19900101     49  1990      1     220500.0         220.5      NaN       NaN
# 1  19900102    161  1990      1     724500.0         724.5      NaN       NaN
# 2  19900103     75  1990      1     337500.0         337.5      NaN       NaN
# 3  19900104     51  1990      1     229500.0         229.5      NaN       NaN
# 4  19900105    196  1990      1     882000.0         882.0      NaN       NaN

# %%
irradiance_df = irradiance_df.rename(columns={'YYYYMMDD': 'DATUM'})
irradiance_df["DATUM"] = pd.to_datetime(irradiance_df['DATUM'], format='%Y%m%d').dt.date
display(irradiance_df.head())
# Out:
#         DATUM      Q  YEAR  MONTH  PAR [J/m2d]  PAR [kJ/m2d]  kPAR_7d  \
# 0  1990-01-01     49  1990      1     220500.0         220.5      NaN
# 1  1990-01-02    161  1990      1     724500.0         724.5      NaN
# 2  1990-01-03     75  1990      1     337500.0         337.5      NaN
# 3  1990-01-04     51  1990      1     229500.0         229.5      NaN
# 4  1990-01-05    196  1990      1     882000.0         882.0      NaN
#
#    kPAR_14d
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
irradiance_df = irradiance_df.drop(columns=['YEAR', 'MONTH'], axis=1)

# %% [markdown]
# ## Merge prepared data into one dataset
# ***
# _We merge the datasets by date and location_

# %% [markdown]
# ### Sort all datasets on date and location (only date for Irradiance)

# %%
abio_sorted = final_abio.sort_values(by=['LOC_CODE', 'DATUM'])
phyto_sorted = phyto_flattened.sort_values(by=['LOC_CODE', 'DATUM'])
irradiance_sorted = irradiance_df.sort_values(by='DATUM')

display("abio_sorted dataset", abio_sorted.head())
display("phyto_sorted dataset", phyto_sorted.head())
display("irradiance_sorted dataset", irradiance_sorted.head())
# Out:
# 'abio_sorted dataset'
#   LOC_CODE       DATUM      TIJD ZS [mg/l] ZICHT [dm] T [oC] SiO2 [umol/L]  \
# 0  DANTZGT  1990-01-10  15:00:00     135.0        2.0    4.0     20.178571
# 0  DANTZGT  1990-02-06  13:40:00     295.0        0.5    6.0           NaN
# 0  DANTZGT  1990-03-08  13:45:00     103.0        3.0    7.3     19.428571
# 0  DANTZGT  1990-04-04  10:00:00     113.0        3.0    8.2      6.285714
# 0  DANTZGT  1990-05-09  15:30:00      20.0       11.0   17.4      1.714286
#
#   SALNTT [DIMSLS] PO4 [umol/L] pH [DIMSLS] NO3 [umol/L] NO2 [umol/L]  \
# 0           29.19     1.645161         7.8    37.571429     3.714286
# 0           27.37          NaN         NaN          NaN          NaN
# 0           24.99     0.709677         8.0    89.285714     2.071429
# 0           28.79     0.806452         8.1         40.0          2.0
# 0           33.28      1.16129         8.3     0.214286     0.142857
#
#   NH4 [umol/L] E [/m] CHLFa [ug/l]
# 0    14.071429    NaN          1.3
# 0          NaN    NaN          NaN
# 0     8.642857    NaN         21.1
# 0     6.428571    NaN         25.0
# 0     1.928571    NaN         10.2
# 'phyto_sorted dataset'
#   LOC_CODE                DATUM       Agl       Dbr       Ezo       Gde  \
# 0  DANTZGT  1990-04-04 00:00:00  3.271842  4.748777  3.572755  3.572755
# 0  DANTZGT  1990-04-24 00:00:00  4.590418  4.669596  3.447933  5.170191
# 0  DANTZGT  1990-05-09 00:00:00  4.669596       NaN  3.271842  3.970672
# 0  DANTZGT  1990-05-23 00:00:00       NaN  1.991226       NaN  4.067889
# 0  DANTZGT  1990-06-07 00:00:00  5.300487  1.968483       NaN  3.307282
#
#         Oau       Omo       Orh       Osi       Ram       Rse       Tec  \
# 0  4.313065  3.748808  3.572755  3.873785  3.271842  3.271842  3.572755
# 0       NaN  3.669689  2.670246  2.574031  1.973128  4.192484       NaN
# 0       NaN  2.670246  1.973128       NaN       NaN  5.192467       NaN
# 0  2.292256  2.292256       NaN  2.466868       NaN  2.989005       NaN
# 0       NaN  2.664642  1.968483       NaN       NaN   4.88552  1.968483
#
#         Tle       Tni       Tro       Dle       Etr       Gfl       Gsp  \
# 0  3.572755  4.669596  4.475787       NaN       NaN       NaN       NaN
# 0       NaN  3.447933  3.447933  1.973128  2.670246  2.274158  2.670246
# 0       NaN       NaN  4.012035       NaN       NaN       NaN  3.669689
# 0       NaN       NaN  3.590842  3.289812       NaN       NaN  4.480036
# 0  3.442009  3.566909  3.496376   2.74351  3.265996       NaN  1.968483
#
#         Nsc       Pbi       Pbr       Pha       Stu       Kgl       Oro  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.670246  4.192484  2.670246  3.891482  2.448706       NaN       NaN
# 0  3.271842  3.669689       NaN       NaN       NaN  1.973128  2.816241
# 0       NaN  3.289812       NaN       NaN       NaN       NaN  3.289812
# 0  2.444045       NaN  1.968483   5.73061       NaN       NaN  4.078674
#
#         Tor       Cdi       Cra       Ore       Ata       Cfu       Cgr  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 0  1.973128       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  3.590842  1.991226  2.767898       NaN       NaN       NaN
# 0  1.968483       NaN       NaN       NaN  2.267172  2.444045  2.568202
#
#         Lan       Pcl       Pmi       Pos       Pse Cden  Aco  Dip  Csu  Mnu  \
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0       NaN       NaN       NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 0  4.456062  2.267172  1.968483  2.267172  3.442009  NaN  NaN  NaN  NaN  NaN
#
#    Pco Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  Gfa  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  Mpe  Pde  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'irradiance_sorted dataset'
#         DATUM      Q  PAR [J/m2d]  PAR [kJ/m2d]  kPAR_7d  kPAR_14d
# 0  1990-01-01     49     220500.0         220.5      NaN       NaN
# 1  1990-01-02    161     724500.0         724.5      NaN       NaN
# 2  1990-01-03     75     337500.0         337.5      NaN       NaN
# 3  1990-01-04     51     229500.0         229.5      NaN       NaN
# 4  1990-01-05    196     882000.0         882.0      NaN       NaN

# %%
merged_abio = pd.merge(abio_sorted, irradiance_sorted, on='DATUM', how='left').sort_values(by=['LOC_CODE', 'DATUM'])
merged_abio
# Out:
#        LOC_CODE       DATUM      TIJD ZS [mg/l] ZICHT [dm] T [oC]  \
# 0       DANTZGT  1990-01-10  15:00:00     135.0        2.0    4.0
# 1       DANTZGT  1990-02-06  13:40:00     295.0        0.5    6.0
# 2       DANTZGT  1990-03-08  13:45:00     103.0        3.0    7.3
# 3       DANTZGT  1990-04-04  10:00:00     113.0        3.0    8.2
# 4       DANTZGT  1990-05-09  15:30:00      20.0       11.0   17.4
# ...         ...         ...       ...       ...        ...    ...
# 13500  WALCRN70  2020-08-13  05:04:00      4.02        NaN   18.5
# 13501  WALCRN70  2020-09-16  09:30:00      4.52        NaN   18.5
# 13502  WALCRN70  2020-10-14  08:25:00      4.99        NaN   15.7
# 13503  WALCRN70  2020-11-17  05:58:00      3.92        NaN   13.9
# 13504  WALCRN70  2020-12-16  10:04:00      6.06        NaN   11.6
#
#       SiO2 [umol/L] SALNTT [DIMSLS] PO4 [umol/L] pH [DIMSLS] NO3 [umol/L]  \
# 0         20.178571           29.19     1.645161         7.8    37.571429
# 1               NaN           27.37          NaN         NaN          NaN
# 2         19.428571           24.99     0.709677         8.0    89.285714
# 3          6.285714           28.79     0.806452         8.1         40.0
# 4          1.714286           33.28      1.16129         8.3     0.214286
# ...             ...             ...          ...         ...          ...
# 13500      0.632143            35.0     0.577419         8.0     0.357143
# 13501         1.275            34.8     0.190323        7.97     2.278571
# 13502      1.682143            34.9     0.206452        8.11     0.357143
# 13503      3.607143            35.0      0.43871        8.13     6.442857
# 13504      3.510714            35.0      0.43871        7.89     8.785714
#
#       NO2 [umol/L] NH4 [umol/L] E [/m] CHLFa [ug/l]      Q  PAR [J/m2d]  \
# 0         3.714286    14.071429    NaN          1.3    100     450000.0
# 1              NaN          NaN    NaN          NaN    603    2713500.0
# 2         2.071429     8.642857    NaN         21.1    543    2443500.0
# 3              2.0     6.428571    NaN         25.0   1491    6709500.0
# 4         0.142857     1.928571    NaN         10.2   1290    5805000.0
# ...            ...          ...    ...          ...    ...          ...
# 13500     0.035714     0.178571    NaN         0.77   2238   10071000.0
# 13501     0.114286     0.485714   0.12         1.47   1377    6196500.0
# 13502     0.242857     0.364286    NaN         2.02    654    2943000.0
# 13503     0.842857     0.178571    NaN         1.59    259    1165500.0
# 13504     0.164286     0.178571    NaN         0.83    194     873000.0
#
#        PAR [kJ/m2d]      kPAR_7d      kPAR_14d
# 0             450.0   513.000000           NaN
# 1            2713.5  1737.000000   1497.857143
# 2            2443.5  2949.428571   2865.857143
# 3            6709.5  6508.285714   5926.821429
# 4            5805.0  9470.571429   9416.892857
# ...             ...          ...           ...
# 13500       10071.0  9970.071429  10099.285714
# 13501        6196.5  6591.857143   5372.678571
# 13502        2943.0  2649.857143   2390.785714
# 13503        1165.5  1021.500000   1665.321429
# 13504         873.0   799.714286    808.714286
#
# [13505 rows x 20 columns]

# %%
# merge abiotic data with biotic data
phyto_sorted['DATUM'] = pd.to_datetime(phyto_sorted['DATUM']).dt.date
merged_df = pd.merge(merged_abio, phyto_sorted, on=['LOC_CODE', 'DATUM'], how='left')

# %%
merged_df
# Out:
#        LOC_CODE       DATUM      TIJD ZS [mg/l] ZICHT [dm] T [oC]  \
# 0       DANTZGT  1990-01-10  15:00:00     135.0        2.0    4.0
# 1       DANTZGT  1990-02-06  13:40:00     295.0        0.5    6.0
# 2       DANTZGT  1990-03-08  13:45:00     103.0        3.0    7.3
# 3       DANTZGT  1990-04-04  10:00:00     113.0        3.0    8.2
# 4       DANTZGT  1990-05-09  15:30:00      20.0       11.0   17.4
# ...         ...         ...       ...       ...        ...    ...
# 13500  WALCRN70  2020-08-13  05:04:00      4.02        NaN   18.5
# 13501  WALCRN70  2020-09-16  09:30:00      4.52        NaN   18.5
# 13502  WALCRN70  2020-10-14  08:25:00      4.99        NaN   15.7
# 13503  WALCRN70  2020-11-17  05:58:00      3.92        NaN   13.9
# 13504  WALCRN70  2020-12-16  10:04:00      6.06        NaN   11.6
#
#       SiO2 [umol/L] SALNTT [DIMSLS] PO4 [umol/L] pH [DIMSLS] NO3 [umol/L]  \
# 0         20.178571           29.19     1.645161         7.8    37.571429
# 1               NaN           27.37          NaN         NaN          NaN
# 2         19.428571           24.99     0.709677         8.0    89.285714
# 3          6.285714           28.79     0.806452         8.1         40.0
# 4          1.714286           33.28      1.16129         8.3     0.214286
# ...             ...             ...          ...         ...          ...
# 13500      0.632143            35.0     0.577419         8.0     0.357143
# 13501         1.275            34.8     0.190323        7.97     2.278571
# 13502      1.682143            34.9     0.206452        8.11     0.357143
# 13503      3.607143            35.0      0.43871        8.13     6.442857
# 13504      3.510714            35.0      0.43871        7.89     8.785714
#
#       NO2 [umol/L] NH4 [umol/L] E [/m] CHLFa [ug/l]      Q  PAR [J/m2d]  \
# 0         3.714286    14.071429    NaN          1.3    100     450000.0
# 1              NaN          NaN    NaN          NaN    603    2713500.0
# 2         2.071429     8.642857    NaN         21.1    543    2443500.0
# 3              2.0     6.428571    NaN         25.0   1491    6709500.0
# 4         0.142857     1.928571    NaN         10.2   1290    5805000.0
# ...            ...          ...    ...          ...    ...          ...
# 13500     0.035714     0.178571    NaN         0.77   2238   10071000.0
# 13501     0.114286     0.485714   0.12         1.47   1377    6196500.0
# 13502     0.242857     0.364286    NaN         2.02    654    2943000.0
# 13503     0.842857     0.178571    NaN         1.59    259    1165500.0
# 13504     0.164286     0.178571    NaN         0.83    194     873000.0
#
#        PAR [kJ/m2d]      kPAR_7d      kPAR_14d       Agl       Dbr       Ezo  \
# 0             450.0   513.000000           NaN       NaN       NaN       NaN
# 1            2713.5  1737.000000   1497.857143       NaN       NaN       NaN
# 2            2443.5  2949.428571   2865.857143       NaN       NaN       NaN
# 3            6709.5  6508.285714   5926.821429  3.271842  4.748777  3.572755
# 4            5805.0  9470.571429   9416.892857  4.669596       NaN  3.271842
# ...             ...          ...           ...       ...       ...       ...
# 13500       10071.0  9970.071429  10099.285714       NaN       NaN       NaN
# 13501        6196.5  6591.857143   5372.678571       NaN       NaN       NaN
# 13502        2943.0  2649.857143   2390.785714       NaN       NaN       NaN
# 13503        1165.5  1021.500000   1665.321429       NaN       NaN       NaN
# 13504         873.0   799.714286    808.714286       NaN       NaN       NaN
#
#             Gde       Oau       Omo       Orh       Osi       Ram       Rse  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      3.572755  4.313065  3.748808  3.572755  3.873785  3.271842  3.271842
# 4      3.970672       NaN  2.670246  1.973128       NaN       NaN  5.192467
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Tec       Tle       Tni       Tro  Dle  Etr  Gfl       Gsp  \
# 0           NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 1           NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 2           NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 3      3.572755  3.572755  4.669596  4.475787  NaN  NaN  NaN       NaN
# 4           NaN       NaN       NaN  4.012035  NaN  NaN  NaN  3.669689
# ...         ...       ...       ...       ...  ...  ...  ...       ...
# 13500       NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13501       NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13502       NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13503       NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13504       NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
#
#             Nsc       Pbi  Pbr  Pha  Stu       Kgl       Oro       Tor  Cdi  \
# 0           NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 1           NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 2           NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 3           NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 4      3.271842  3.669689  NaN  NaN  NaN  1.973128  2.816241  1.973128  NaN
# ...         ...       ...  ...  ...  ...       ...       ...       ...  ...
# 13500       NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 13501       NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 13502       NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 13503       NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
# 13504       NaN       NaN  NaN  NaN  NaN       NaN       NaN       NaN  NaN
#
#        Cra  Ore  Ata  Cfu  Cgr  Lan  Pcl  Pmi  Pos  Pse Cden  Aco  Dip  Csu  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Mnu  Pco Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Pan  Gfa  Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Edu  Mpe  Pde  Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [13505 rows x 100 columns]

# %% [markdown]
# ### Write temporary merged_df to excel

# %%
# filename = '../../data/MERGED_DATA_TEMP.xlsx'
# sheetname = 'MERGE'

# with pd.ExcelWriter(filename, mode='w') as writer:  
#     merged_df.to_excel(writer, sheet_name=sheetname, index=False)

# print(f"Data written to sheet '{sheetname}' in '{filename}'")

# %% [markdown]
# ## Calculate extra columns based on recomendations from Dr. Louis Peperzak
# ***
# _Variables:_
# To be calculated:
# - DIN (NH4+NO3+NO2), and nutrient ratios (DIN:SRP, DIN:Si).
# - Kd:	Extinction coefficient (1/m), calculated from Sal,  TSS and Chla (model 2012a) or from Secchi (model 2012b)
# > KD = 3.504 - 0.098 * Sal + 0.025 * TSS + 0.006 * CHla or  Log Kd = -0.673*logSecchi + 0.854, r2=0.75
#
# - Im (Jm2d)	Daily Water Column Irradiance (J/m².d) (Peperzak 1993)
# - Im (kJm2d)	Daily Water Column Irradiance (kJ/m².d) (Peperzak 1993)
# - Interpolation for one or more missing values

# %% [markdown]
# #### DIN (NH4+NO3+NO2), and nutrient ratios (DIN:SRP, DIN:Si).

# %%
merged_df["DIN"] = merged_df['NO3 [umol/L]'] + merged_df['NH4 [umol/L]'] + merged_df['NO2 [umol/L]']
merged_df['DIN:SRP'] = merged_df['DIN']/merged_df['PO4 [umol/L]']
merged_df['DIN:SI'] = merged_df['DIN']/merged_df['SiO2 [umol/L]']
merged_df['SRP:SI'] = merged_df['PO4 [umol/L]'] / merged_df['SiO2 [umol/L]']
merged_df.head(20)

print(list(merged_df.columns))
# Out:
# ['LOC_CODE', 'DATUM', 'TIJD', 'ZS [mg/l]', 'ZICHT [dm]', 'T [oC]', 'SiO2 [umol/L]', 'SALNTT [DIMSLS]', 'PO4 [umol/L]', 'pH [DIMSLS]', 'NO3 [umol/L]', 'NO2 [umol/L]', 'NH4 [umol/L]', 'E [/m]', 'CHLFa [ug/l]', '    Q', 'PAR [J/m2d]', 'PAR [kJ/m2d]', 'kPAR_7d', 'kPAR_14d', 'Agl', 'Dbr', 'Ezo', 'Gde', 'Oau', 'Omo', 'Orh', 'Osi', 'Ram', 'Rse', 'Tec', 'Tle', 'Tni', 'Tro', 'Dle', 'Etr', 'Gfl', 'Gsp', 'Nsc', 'Pbi', 'Pbr', 'Pha', 'Stu', 'Kgl', 'Oro', 'Tor', 'Cdi', 'Cra', 'Ore', 'Ata', 'Cfu', 'Cgr', 'Lan', 'Pcl', 'Pmi', 'Pos', 'Pse', 'Cden', 'Aco', 'Dip', 'Csu', 'Mnu', 'Pco', 'Cdeb', 'Cwa', 'Pba', 'Dac', 'Ptr', 'Lun', 'Nsi', 'Rst', 'Pst', 'Acn', 'Tno', 'Ccu', 'Pan', 'Gfa', 'Hta', 'Dsp', 'Psu', 'Cei', 'Ndi', 'Cda', 'Dro', 'Cha', 'Pac', 'Cau', 'Coc', 'Pte', 'Edu', 'Mpe', 'Pde', 'Plo', 'Dpu', 'Rte', 'Fja', 'Hak', 'Mhe', 'Dno', 'Dat', 'DIN', 'DIN:SRP', 'DIN:SI', 'SRP:SI']

# %% [markdown]
# #### Kd:	Extinction coefficient (1/m), calculated from Sal,  TSS and Chla (model 2012a) or from Secchi (model 2012b)
# > KD = 3.504 - 0.098 * Sal + 0.025 * TSS + 0.006 * CHla or  Log Kd = -0.673*logSecchi + 0.854, r2=0.75

# %%
def calculate_E(row):
    if pd.isna(row['E [/m]']):
        if not pd.isna(row['SALNTT [DIMSLS]']) and not pd.isna(row['T [oC]']) and not pd.isna(row['CHLFa [ug/l]']):
            row['E [/m]'] = 3.504 - 0.098 * row['SALNTT [DIMSLS]'] + 0.025 * row['T [oC]'] + 0.006 * row['CHLFa [ug/l]']
            row["E_method"] = "2012a"
        elif not pd.isna(row['ZICHT [dm]']) and row['ZICHT [dm]'] > 0:
            log_kd = -0.673 * np.log10(row['ZICHT [dm]']) + 0.854
            row['E [/m]'] = 10 ** log_kd
            row["E_method"] = "2012b"
        else:
            row["E_method"] = "interpolated"
    else:
        row["E_method"] = "measured"
    return row

pd.set_option('display.max_columns', 100)

# Apply the function to each row
merged_df = merged_df.apply(calculate_E, axis=1)

display(merged_df)
# Out:
#        LOC_CODE       DATUM      TIJD  ZS [mg/l]  ZICHT [dm]  T [oC]  \
# 0       DANTZGT  1990-01-10  15:00:00     135.00         2.0     4.0
# 1       DANTZGT  1990-02-06  13:40:00     295.00         0.5     6.0
# 2       DANTZGT  1990-03-08  13:45:00     103.00         3.0     7.3
# 3       DANTZGT  1990-04-04  10:00:00     113.00         3.0     8.2
# 4       DANTZGT  1990-05-09  15:30:00      20.00        11.0    17.4
# ...         ...         ...       ...        ...         ...     ...
# 13500  WALCRN70  2020-08-13  05:04:00       4.02         NaN    18.5
# 13501  WALCRN70  2020-09-16  09:30:00       4.52         NaN    18.5
# 13502  WALCRN70  2020-10-14  08:25:00       4.99         NaN    15.7
# 13503  WALCRN70  2020-11-17  05:58:00       3.92         NaN    13.9
# 13504  WALCRN70  2020-12-16  10:04:00       6.06         NaN    11.6
#
#        SiO2 [umol/L]  SALNTT [DIMSLS]  PO4 [umol/L]  pH [DIMSLS]  \
# 0          20.178571            29.19      1.645161         7.80
# 1                NaN            27.37           NaN          NaN
# 2          19.428571            24.99      0.709677         8.00
# 3           6.285714            28.79      0.806452         8.10
# 4           1.714286            33.28      1.161290         8.30
# ...              ...              ...           ...          ...
# 13500       0.632143            35.00      0.577419         8.00
# 13501       1.275000            34.80      0.190323         7.97
# 13502       1.682143            34.90      0.206452         8.11
# 13503       3.607143            35.00      0.438710         8.13
# 13504       3.510714            35.00      0.438710         7.89
#
#        NO3 [umol/L]  NO2 [umol/L]  NH4 [umol/L]     E [/m]  CHLFa [ug/l]  \
# 0         37.571429      3.714286     14.071429   0.751180          1.30
# 1               NaN           NaN           NaN  11.391822           NaN
# 2         89.285714      2.071429      8.642857   1.364080         21.10
# 3         40.000000      2.000000      6.428571   1.037580         25.00
# 4          0.214286      0.142857      1.928571   0.738760         10.20
# ...             ...           ...           ...        ...           ...
# 13500      0.357143      0.035714      0.178571   0.541120          0.77
# 13501      2.278571      0.114286      0.485714   0.120000          1.47
# 13502      0.357143      0.242857      0.364286   0.488420          2.02
# 13503      6.442857      0.842857      0.178571   0.431040          1.59
# 13504      8.785714      0.164286      0.178571   0.368980          0.83
#
#            Q  PAR [J/m2d]  PAR [kJ/m2d]      kPAR_7d      kPAR_14d       Agl  \
# 0        100     450000.0         450.0   513.000000           NaN       NaN
# 1        603    2713500.0        2713.5  1737.000000   1497.857143       NaN
# 2        543    2443500.0        2443.5  2949.428571   2865.857143       NaN
# 3       1491    6709500.0        6709.5  6508.285714   5926.821429  3.271842
# 4       1290    5805000.0        5805.0  9470.571429   9416.892857  4.669596
# ...      ...          ...           ...          ...           ...       ...
# 13500   2238   10071000.0       10071.0  9970.071429  10099.285714       NaN
# 13501   1377    6196500.0        6196.5  6591.857143   5372.678571       NaN
# 13502    654    2943000.0        2943.0  2649.857143   2390.785714       NaN
# 13503    259    1165500.0        1165.5  1021.500000   1665.321429       NaN
# 13504    194     873000.0         873.0   799.714286    808.714286       NaN
#
#             Dbr       Ezo       Gde       Oau       Omo       Orh       Osi  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      4.748777  3.572755  3.572755  4.313065  3.748808  3.572755  3.873785
# 4           NaN  3.271842  3.970672       NaN  2.670246  1.973128       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Ram       Rse       Tec       Tle       Tni       Tro  Dle  Etr  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 3      3.271842  3.271842  3.572755  3.572755  4.669596  4.475787  NaN  NaN
# 4           NaN  5.192467       NaN       NaN       NaN  4.012035  NaN  NaN
# ...         ...       ...       ...       ...       ...       ...  ...  ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
#
#        Gfl       Gsp       Nsc       Pbi  Pbr  Pha  Stu       Kgl       Oro  \
# 0      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 4      NaN  3.669689  3.271842  3.669689  NaN  NaN  NaN  1.973128  2.816241
# ...    ...       ...       ...       ...  ...  ...  ...       ...       ...
# 13500  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13501  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13502  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13503  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13504  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
#
#             Tor  Cdi  Cra  Ore  Ata  ...  Pos  Pse  Cden  Aco  Dip  Csu  Mnu  \
# 0           NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 1           NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 2           NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 3           NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 4      1.973128  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# ...         ...  ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...  ...
# 13500       NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 13501       NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 13502       NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 13503       NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 13504       NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN   NaN  NaN  NaN  NaN  NaN
#
#        Pco  Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  \
# 0      NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Gfa  Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Mpe  Pde  Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat         DIN  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   55.357143
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  100.000000
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   48.428571
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    2.285714
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...         ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    0.571429
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    2.878571
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    0.964286
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    7.464286
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    9.128571
#
#           DIN:SRP    DIN:SI    SRP:SI  E_method
# 0       33.648459  2.743363  0.081530     2012a
# 1             NaN       NaN       NaN     2012b
# 2      140.909091  5.147059  0.036528     2012a
# 3       60.051429  7.704545  0.128299     2012a
# 4        1.968254  1.333333  0.677419     2012a
# ...           ...       ...       ...       ...
# 13500    0.989625  0.903955  0.913432     2012a
# 13501   15.124697  2.257703  0.149273  measured
# 13502    4.670759  0.573248  0.122731     2012a
# 13503   17.014181  2.069307  0.121622     2012a
# 13504   20.807773  2.600203  0.124963     2012a
#
# [13505 rows x 105 columns]

# %%
# def calculate_E(row):
#     if pd.isna(row['E [/m]']):
#         if not pd.isna(row['SALNTT [DIMSLS]']) and not pd.isna(row['T [oC]']) and not pd.isna(row['CHLFa [ug/l]']):
#             row['E [/m]'] = 3.504 - 0.098 * row['SALNTT [DIMSLS]'] + 0.025 * row['T [oC]'] + 0.006 * row['CHLFa [ug/l]']
#         elif not pd.isna(row['ZICHT [dm]']):
#             log_kd = -0.673 * np.log10(row['ZICHT [dm]']) + 0.854
#             row['E [/m]'] = 10 ** log_kd
#     return row

# # Apply the function to each row
# merged_df = merged_df.apply(calculate_E, axis=1)

# %% [markdown]
# #### Im (Jm2d)	Daily Water Column Irradiance (J/m².d) (Peperzak 1993)
# - Im = DI (PAR) x (1 - EXP(-Kd x h)/(Kd x h)

# %%
loc_df = pd.read_excel('../../miscellaneous/2024_NIOZ_UvA_Plankton_ABIO_coupling.xlsx', sheet_name='Tables ABIO', skiprows=2, nrows=27, usecols="A,B, D:H, J")
loc_df
# Out:
#       DONAR CODE                DONAR-DESCRIPTION    LOC LATITUDE ( WGS84 )  \
# 0       GROOTGND                 Groote Gat noord    EDG        NB 53 18 15
# 1        HUIBGOT                  Huibertgat oost    EDH       NB 53 33 33
# 2         DREISR                        Dreischor    GMD        NB 51 42 53
# 3         GOERE6          Goeree 6 km uit de kust   GOE6        NB 51 52 08
# 4      NOORDWK10      Noordwijk 10 km uit de kust   NW10        NB 52 18 05
# 5       NOORDWK2       Noordwijk 2 km uit de kust    NW2        NB 52 15 38
# 6      NOORDWK20      Noordwijk 20 km uit de kust   NW20        NB 52 20 27
# 7      NOORDWK70      Noordwijk 70 km uit de kust   NW70        NB 52 35 07
# 8         LODSGT                     Lodijkse Gat    OSL        NB 51 30 55
# 9       ROTTMPT3   Rottumerplaat 3 km uit de kust    RP3        NB 53 33 55
# 10     ROTTMPT50  Rottumerplaat 50 km uit de kust   RP50        NB 53 57 11
# 11     ROTTMPT70  Rottumerplaat 70 km uit de kust   RP70        NB 54 07 02
# 12      TERSLG10   Terschelling 10 km uit de kust   TS10        NB 53 27 37
# 13     TERSLG100  Terschelling 100 km uit de kust  TS100        NB 54 08 55
# 14     TERSLG135  Terschelling 135 km uit de kust  TS135        NB 54 24 53
# 15     TERSLG175  Terschelling 175 km uit de kust  TS175        NB 54 43 06
# 16     TERSLG235  Terschelling 235 km uit de kust  TS235        NB 55 10 17
# 17       TERSLG4    Terschelling 4 km uit de kust    TS4        NB 53 24 52
# 18    SOELKKPDOT           Soelekerkerpolder oost    VMS        NB 51 32 32
# 19       WALCRN2       Walcheren 2 km uit de kust    WA2        NB 51 32 53
# 20      WALCRN20      Walcheren 20 km uit de kust   WA20        NB 51 39 28
# 21      WALCRN70      Walcheren 70 km uit de kust   WA70        NB 51 57 22
# 22       HANSWGL                   Hansweert geul    WSH        NB 51 26 10
# 23   SCHAARVODDL            Schaar van Ouden Doel    WSO        NB 51 21 01
# 24  VLISSGBISSVH             Vlissingen boei SSVH    WSV        NB 51 24 43
# 25       DANTZGT                       Dantziggat    WZD        NB 53 24 04
# 26       MARSDND                   Marsdiep noord    WZM        NB 52 58 57
#
#    LONGITUDE ( WGS84 )        WATERBODY       TYPE  h (m)
# 0          OL 07 09 24      EEMSDOLLARD  ESTUARINE    5.9
# 1          OL 06 39 40      EEMSDOLLARD  ESTUARINE   27.9
# 2          OL 03 59 58  GREVELINGENMEER       LAKE   19.3
# 3          OL 03 52 20         NOORDZEE      COAST    8.8
# 4          OL 04 18 04         NOORDZEE      COAST   18.2
# 5          OL 04 24 17         NOORDZEE      COAST   13.0
# 6          OL 04 10 25         NOORDZEE      COAST   20.0
# 7          OL 03 31 48         NOORDZEE    OPENSEA   28.0
# 8          OL 04 07 37    OOSTERSCHELDE  ESTUARINE    4.8
# 9          OL 06 33 46         NOORDZEE      COAST    9.0
# 10         OL 06 18 31         NOORDZEE    OPENSEA   20.0
# 11         OL 06 12 46         NOORDZEE    OPENSEA   24.0
# 12         OL 05 05 58         NOORDZEE      COAST   24.3
# 13         OL 04 20 26         NOORDZEE    OPENSEA   48.6
# 14         OL 04 02 23         NOORDZEE    OPENSEA   35.0
# 15         OL 03 41 25         NOORDZEE    OPENSEA   35.0
# 16         OL 03 09 22         NOORDZEE    OPENSEA   18.0
# 17         OL 05 08 57         NOORDZEE      COAST   13.1
# 18         OL 03 43 51       VEERSEMEER       LAKE   25.0
# 19         OL 03 24 34         NOORDZEE      COAST    8.0
# 20         OL 03 13 09         NOORDZEE      COAST   22.0
# 21         OL 02 40 40         NOORDZEE    OPENSEA   30.0
# 22         OL 04 00 51    WESTERSCHELDE  ESTUARINE   17.3
# 23         OL 04 15 02    WESTERSCHELDE  ESTUARINE   14.9
# 24         OL 03 33 56    WESTERSCHELDE  ESTUARINE   18.2
# 25         OL 05 43 37        WADDENZEE  ESTUARINE    9.5
# 26         OL 04 45 00        WADDENZEE  ESTUARINE   15.9

# %%
# merged_df['IM [Jm2d]'] = merged_df['PAR [J/m2d]'] * (1-np.exp((-1 * [merged_df['E [/m]']]) * h))
for location in merged_df["LOC_CODE"].unique():
    h = loc_df.loc[loc_df['DONAR CODE'] == location, 'h (m)'].values[0]
    merged_df.loc[merged_df['LOC_CODE'] == location, 'IM [Jm2d]'] = merged_df.loc[merged_df['LOC_CODE'] == location, 'PAR [J/m2d]'] * (1-np.exp((-1 * merged_df.loc[merged_df['LOC_CODE'] == location, 'E [/m]']) * h))
merged_df
# Out:
# C:\Users\Ardjano Mark\AppData\Local\Temp\ipykernel_5016\690874902.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df.loc[merged_df['LOC_CODE'] == location, 'IM [Jm2d]'] = merged_df.loc[merged_df['LOC_CODE'] == location, 'PAR [J/m2d]'] * (1-np.exp((-1 * merged_df.loc[merged_df['LOC_CODE'] == location, 'E [/m]']) * h))
#        LOC_CODE       DATUM      TIJD  ZS [mg/l]  ZICHT [dm]  T [oC]  \
# 0       DANTZGT  1990-01-10  15:00:00     135.00         2.0     4.0
# 1       DANTZGT  1990-02-06  13:40:00     295.00         0.5     6.0
# 2       DANTZGT  1990-03-08  13:45:00     103.00         3.0     7.3
# 3       DANTZGT  1990-04-04  10:00:00     113.00         3.0     8.2
# 4       DANTZGT  1990-05-09  15:30:00      20.00        11.0    17.4
# ...         ...         ...       ...        ...         ...     ...
# 13500  WALCRN70  2020-08-13  05:04:00       4.02         NaN    18.5
# 13501  WALCRN70  2020-09-16  09:30:00       4.52         NaN    18.5
# 13502  WALCRN70  2020-10-14  08:25:00       4.99         NaN    15.7
# 13503  WALCRN70  2020-11-17  05:58:00       3.92         NaN    13.9
# 13504  WALCRN70  2020-12-16  10:04:00       6.06         NaN    11.6
#
#        SiO2 [umol/L]  SALNTT [DIMSLS]  PO4 [umol/L]  pH [DIMSLS]  \
# 0          20.178571            29.19      1.645161         7.80
# 1                NaN            27.37           NaN          NaN
# 2          19.428571            24.99      0.709677         8.00
# 3           6.285714            28.79      0.806452         8.10
# 4           1.714286            33.28      1.161290         8.30
# ...              ...              ...           ...          ...
# 13500       0.632143            35.00      0.577419         8.00
# 13501       1.275000            34.80      0.190323         7.97
# 13502       1.682143            34.90      0.206452         8.11
# 13503       3.607143            35.00      0.438710         8.13
# 13504       3.510714            35.00      0.438710         7.89
#
#        NO3 [umol/L]  NO2 [umol/L]  NH4 [umol/L]     E [/m]  CHLFa [ug/l]  \
# 0         37.571429      3.714286     14.071429   0.751180          1.30
# 1               NaN           NaN           NaN  11.391822           NaN
# 2         89.285714      2.071429      8.642857   1.364080         21.10
# 3         40.000000      2.000000      6.428571   1.037580         25.00
# 4          0.214286      0.142857      1.928571   0.738760         10.20
# ...             ...           ...           ...        ...           ...
# 13500      0.357143      0.035714      0.178571   0.541120          0.77
# 13501      2.278571      0.114286      0.485714   0.120000          1.47
# 13502      0.357143      0.242857      0.364286   0.488420          2.02
# 13503      6.442857      0.842857      0.178571   0.431040          1.59
# 13504      8.785714      0.164286      0.178571   0.368980          0.83
#
#            Q  PAR [J/m2d]  PAR [kJ/m2d]      kPAR_7d      kPAR_14d       Agl  \
# 0        100     450000.0         450.0   513.000000           NaN       NaN
# 1        603    2713500.0        2713.5  1737.000000   1497.857143       NaN
# 2        543    2443500.0        2443.5  2949.428571   2865.857143       NaN
# 3       1491    6709500.0        6709.5  6508.285714   5926.821429  3.271842
# 4       1290    5805000.0        5805.0  9470.571429   9416.892857  4.669596
# ...      ...          ...           ...          ...           ...       ...
# 13500   2238   10071000.0       10071.0  9970.071429  10099.285714       NaN
# 13501   1377    6196500.0        6196.5  6591.857143   5372.678571       NaN
# 13502    654    2943000.0        2943.0  2649.857143   2390.785714       NaN
# 13503    259    1165500.0        1165.5  1021.500000   1665.321429       NaN
# 13504    194     873000.0         873.0   799.714286    808.714286       NaN
#
#             Dbr       Ezo       Gde       Oau       Omo       Orh       Osi  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      4.748777  3.572755  3.572755  4.313065  3.748808  3.572755  3.873785
# 4           NaN  3.271842  3.970672       NaN  2.670246  1.973128       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Ram       Rse       Tec       Tle       Tni       Tro  Dle  Etr  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 3      3.271842  3.271842  3.572755  3.572755  4.669596  4.475787  NaN  NaN
# 4           NaN  5.192467       NaN       NaN       NaN  4.012035  NaN  NaN
# ...         ...       ...       ...       ...       ...       ...  ...  ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN  NaN  NaN
#
#        Gfl       Gsp       Nsc       Pbi  Pbr  Pha  Stu       Kgl       Oro  \
# 0      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 4      NaN  3.669689  3.271842  3.669689  NaN  NaN  NaN  1.973128  2.816241
# ...    ...       ...       ...       ...  ...  ...  ...       ...       ...
# 13500  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13501  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13502  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13503  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
# 13504  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN       NaN
#
#             Tor  Cdi  Cra  Ore  Ata  ...  Pse  Cden  Aco  Dip  Csu  Mnu  Pco  \
# 0           NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1           NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 2           NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 3           NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 4      1.973128  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...  ...  ...
# 13500       NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13501       NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13502       NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13503       NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13504       NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN  NaN  NaN  NaN  NaN  NaN
#
#        Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  Gfa  \
# 0       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  Mpe  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Pde  Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat         DIN     DIN:SRP  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   55.357143   33.648459
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN         NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  100.000000  140.909091
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   48.428571   60.051429
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    2.285714    1.968254
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...         ...         ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    0.571429    0.989625
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    2.878571   15.124697
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    0.964286    4.670759
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    7.464286   17.014181
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    9.128571   20.807773
#
#          DIN:SI    SRP:SI  E_method     IM [Jm2d]
# 0      2.743363  0.081530     2012a  4.496419e+05
# 1           NaN       NaN     2012b  2.713500e+06
# 2      5.147059  0.036528     2012a  2.443494e+06
# 3      7.704545  0.128299     2012a  6.709149e+06
# 4      1.333333  0.677419     2012a  5.799802e+06
# ...         ...       ...       ...           ...
# 13500  0.903955  0.913432     2012a  1.007100e+07
# 13501  2.257703  0.149273  measured  6.027189e+06
# 13502  0.573248  0.122731     2012a  2.942999e+06
# 13503  2.069307  0.121622     2012a  1.165497e+06
# 13504  2.600203  0.124963     2012a  8.729864e+05
#
# [13505 rows x 106 columns]

# %% [markdown]
# #### Move abiotic columns to the front

# %%
abiotic_columns = ['LOC_CODE', 'DATUM', 'TIJD', 'ZS [mg/l]', 'ZICHT [dm]', 'T [oC]', 'SiO2 [umol/L]',
                    'SALNTT [DIMSLS]', 'PO4 [umol/L]', 'pH [DIMSLS]', 'NO3 [umol/L]', 'NO2 [umol/L]',
                      'NH4 [umol/L]', 'E [/m]', 'E_method', 'CHLFa [ug/l]', '    Q', 'PAR [J/m2d]', 'PAR [kJ/m2d]',
                        'kPAR_7d', 'kPAR_14d', 'DIN', 'DIN:SRP', 'DIN:SI', 'SRP:SI', 'IM [Jm2d]']
biotic_columns = list(unique_SPEC)
merged_df = merged_df[abiotic_columns + biotic_columns]
merged_df
# Out:
#        LOC_CODE       DATUM      TIJD  ZS [mg/l]  ZICHT [dm]  T [oC]  \
# 0       DANTZGT  1990-01-10  15:00:00     135.00         2.0     4.0
# 1       DANTZGT  1990-02-06  13:40:00     295.00         0.5     6.0
# 2       DANTZGT  1990-03-08  13:45:00     103.00         3.0     7.3
# 3       DANTZGT  1990-04-04  10:00:00     113.00         3.0     8.2
# 4       DANTZGT  1990-05-09  15:30:00      20.00        11.0    17.4
# ...         ...         ...       ...        ...         ...     ...
# 13500  WALCRN70  2020-08-13  05:04:00       4.02         NaN    18.5
# 13501  WALCRN70  2020-09-16  09:30:00       4.52         NaN    18.5
# 13502  WALCRN70  2020-10-14  08:25:00       4.99         NaN    15.7
# 13503  WALCRN70  2020-11-17  05:58:00       3.92         NaN    13.9
# 13504  WALCRN70  2020-12-16  10:04:00       6.06         NaN    11.6
#
#        SiO2 [umol/L]  SALNTT [DIMSLS]  PO4 [umol/L]  pH [DIMSLS]  \
# 0          20.178571            29.19      1.645161         7.80
# 1                NaN            27.37           NaN          NaN
# 2          19.428571            24.99      0.709677         8.00
# 3           6.285714            28.79      0.806452         8.10
# 4           1.714286            33.28      1.161290         8.30
# ...              ...              ...           ...          ...
# 13500       0.632143            35.00      0.577419         8.00
# 13501       1.275000            34.80      0.190323         7.97
# 13502       1.682143            34.90      0.206452         8.11
# 13503       3.607143            35.00      0.438710         8.13
# 13504       3.510714            35.00      0.438710         7.89
#
#        NO3 [umol/L]  NO2 [umol/L]  NH4 [umol/L]     E [/m]  E_method  \
# 0         37.571429      3.714286     14.071429   0.751180     2012a
# 1               NaN           NaN           NaN  11.391822     2012b
# 2         89.285714      2.071429      8.642857   1.364080     2012a
# 3         40.000000      2.000000      6.428571   1.037580     2012a
# 4          0.214286      0.142857      1.928571   0.738760     2012a
# ...             ...           ...           ...        ...       ...
# 13500      0.357143      0.035714      0.178571   0.541120     2012a
# 13501      2.278571      0.114286      0.485714   0.120000  measured
# 13502      0.357143      0.242857      0.364286   0.488420     2012a
# 13503      6.442857      0.842857      0.178571   0.431040     2012a
# 13504      8.785714      0.164286      0.178571   0.368980     2012a
#
#        CHLFa [ug/l]      Q  PAR [J/m2d]  PAR [kJ/m2d]      kPAR_7d  \
# 0              1.30    100     450000.0         450.0   513.000000
# 1               NaN    603    2713500.0        2713.5  1737.000000
# 2             21.10    543    2443500.0        2443.5  2949.428571
# 3             25.00   1491    6709500.0        6709.5  6508.285714
# 4             10.20   1290    5805000.0        5805.0  9470.571429
# ...             ...    ...          ...           ...          ...
# 13500          0.77   2238   10071000.0       10071.0  9970.071429
# 13501          1.47   1377    6196500.0        6196.5  6591.857143
# 13502          2.02    654    2943000.0        2943.0  2649.857143
# 13503          1.59    259    1165500.0        1165.5  1021.500000
# 13504          0.83    194     873000.0         873.0   799.714286
#
#            kPAR_14d         DIN     DIN:SRP    DIN:SI    SRP:SI     IM [Jm2d]  \
# 0               NaN   55.357143   33.648459  2.743363  0.081530  4.496419e+05
# 1       1497.857143         NaN         NaN       NaN       NaN  2.713500e+06
# 2       2865.857143  100.000000  140.909091  5.147059  0.036528  2.443494e+06
# 3       5926.821429   48.428571   60.051429  7.704545  0.128299  6.709149e+06
# 4       9416.892857    2.285714    1.968254  1.333333  0.677419  5.799802e+06
# ...             ...         ...         ...       ...       ...           ...
# 13500  10099.285714    0.571429    0.989625  0.903955  0.913432  1.007100e+07
# 13501   5372.678571    2.878571   15.124697  2.257703  0.149273  6.027189e+06
# 13502   2390.785714    0.964286    4.670759  0.573248  0.122731  2.942999e+06
# 13503   1665.321429    7.464286   17.014181  2.069307  0.121622  1.165497e+06
# 13504    808.714286    9.128571   20.807773  2.600203  0.124963  8.729864e+05
#
#             Agl       Dbr       Ezo       Gde       Oau       Omo       Orh  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      3.271842  4.748777  3.572755  3.572755  4.313065  3.748808  3.572755
# 4      4.669596       NaN  3.271842  3.970672       NaN  2.670246  1.973128
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Osi       Ram       Rse       Tec       Tle       Tni       Tro  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      3.873785  3.271842  3.271842  3.572755  3.572755  4.669596  4.475787
# 4           NaN       NaN  5.192467       NaN       NaN       NaN  4.012035
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        Dle  Etr  Gfl       Gsp       Nsc       Pbi  Pbr  Pha  Stu       Kgl  \
# 0      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 1      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 2      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 3      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 4      NaN  NaN  NaN  3.669689  3.271842  3.669689  NaN  NaN  NaN  1.973128
# ...    ...  ...  ...       ...       ...       ...  ...  ...  ...       ...
# 13500  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13501  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13502  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13503  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13504  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
#
#        ...  Cfu  Cgr  Lan  Pcl  Pmi  Pos  Pse  Cden  Aco  Dip  Csu  Mnu  Pco  \
# 0      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 2      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 3      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 4      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...  ...  ...
# 13500  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13501  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13502  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13503  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13504  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
#
#        Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  Gfa  \
# 0       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  Mpe  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Pde  Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [13505 rows x 106 columns]

# %% [markdown]
# ### Interpolation for missing values in ABIOTIC DATA

# %%
interpolation_columns = ['ZS [mg/l]', 'T [oC]', 'SiO2 [umol/L]',
                    'SALNTT [DIMSLS]', 'PO4 [umol/L]', 'pH [DIMSLS]', 'NO3 [umol/L]', 'NO2 [umol/L]',
                      'NH4 [umol/L]', 'E [/m]', 'CHLFa [ug/l]', 'DIN', 'DIN:SRP', 'DIN:SI', 'SRP:SI']


missing_mask = merged_df[interpolation_columns].isna()
missing_mask
# Out:
#        ZS [mg/l]  T [oC]  SiO2 [umol/L]  SALNTT [DIMSLS]  PO4 [umol/L]  \
# 0          False   False          False            False         False
# 1          False   False           True            False          True
# 2          False   False          False            False         False
# 3          False   False          False            False         False
# 4          False   False          False            False         False
# ...          ...     ...            ...              ...           ...
# 13500      False   False          False            False         False
# 13501      False   False          False            False         False
# 13502      False   False          False            False         False
# 13503      False   False          False            False         False
# 13504      False   False          False            False         False
#
#        pH [DIMSLS]  NO3 [umol/L]  NO2 [umol/L]  NH4 [umol/L]  E [/m]  \
# 0            False         False         False         False   False
# 1             True          True          True          True   False
# 2            False         False         False         False   False
# 3            False         False         False         False   False
# 4            False         False         False         False   False
# ...            ...           ...           ...           ...     ...
# 13500        False         False         False         False   False
# 13501        False         False         False         False   False
# 13502        False         False         False         False   False
# 13503        False         False         False         False   False
# 13504        False         False         False         False   False
#
#        CHLFa [ug/l]    DIN  DIN:SRP  DIN:SI  SRP:SI
# 0             False  False    False   False   False
# 1              True   True     True    True    True
# 2             False  False    False   False   False
# 3             False  False    False   False   False
# 4             False  False    False   False   False
# ...             ...    ...      ...     ...     ...
# 13500         False  False    False   False   False
# 13501         False  False    False   False   False
# 13502         False  False    False   False   False
# 13503         False  False    False   False   False
# 13504         False  False    False   False   False
#
# [13505 rows x 15 columns]

# %% [markdown]
# #### interpolate in interpolatable columns

# %%
merged_interpolated = merged_df.copy()


for column in interpolation_columns:
    merged_interpolated[column] = merged_interpolated[column].interpolate(method='linear')

merged_interpolated
# Out:
#        LOC_CODE       DATUM      TIJD  ZS [mg/l]  ZICHT [dm]  T [oC]  \
# 0       DANTZGT  1990-01-10  15:00:00     135.00         2.0     4.0
# 1       DANTZGT  1990-02-06  13:40:00     295.00         0.5     6.0
# 2       DANTZGT  1990-03-08  13:45:00     103.00         3.0     7.3
# 3       DANTZGT  1990-04-04  10:00:00     113.00         3.0     8.2
# 4       DANTZGT  1990-05-09  15:30:00      20.00        11.0    17.4
# ...         ...         ...       ...        ...         ...     ...
# 13500  WALCRN70  2020-08-13  05:04:00       4.02         NaN    18.5
# 13501  WALCRN70  2020-09-16  09:30:00       4.52         NaN    18.5
# 13502  WALCRN70  2020-10-14  08:25:00       4.99         NaN    15.7
# 13503  WALCRN70  2020-11-17  05:58:00       3.92         NaN    13.9
# 13504  WALCRN70  2020-12-16  10:04:00       6.06         NaN    11.6
#
#        SiO2 [umol/L]  SALNTT [DIMSLS]  PO4 [umol/L]  pH [DIMSLS]  \
# 0          20.178571            29.19      1.645161         7.80
# 1          19.803571            27.37      1.177419         7.90
# 2          19.428571            24.99      0.709677         8.00
# 3           6.285714            28.79      0.806452         8.10
# 4           1.714286            33.28      1.161290         8.30
# ...              ...              ...           ...          ...
# 13500       0.632143            35.00      0.577419         8.00
# 13501       1.275000            34.80      0.190323         7.97
# 13502       1.682143            34.90      0.206452         8.11
# 13503       3.607143            35.00      0.438710         8.13
# 13504       3.510714            35.00      0.438710         7.89
#
#        NO3 [umol/L]  NO2 [umol/L]  NH4 [umol/L]     E [/m]  E_method  \
# 0         37.571429      3.714286     14.071429   0.751180     2012a
# 1         63.428571      2.892857     11.357143  11.391822     2012b
# 2         89.285714      2.071429      8.642857   1.364080     2012a
# 3         40.000000      2.000000      6.428571   1.037580     2012a
# 4          0.214286      0.142857      1.928571   0.738760     2012a
# ...             ...           ...           ...        ...       ...
# 13500      0.357143      0.035714      0.178571   0.541120     2012a
# 13501      2.278571      0.114286      0.485714   0.120000  measured
# 13502      0.357143      0.242857      0.364286   0.488420     2012a
# 13503      6.442857      0.842857      0.178571   0.431040     2012a
# 13504      8.785714      0.164286      0.178571   0.368980     2012a
#
#        CHLFa [ug/l]      Q  PAR [J/m2d]  PAR [kJ/m2d]      kPAR_7d  \
# 0              1.30    100     450000.0         450.0   513.000000
# 1             11.20    603    2713500.0        2713.5  1737.000000
# 2             21.10    543    2443500.0        2443.5  2949.428571
# 3             25.00   1491    6709500.0        6709.5  6508.285714
# 4             10.20   1290    5805000.0        5805.0  9470.571429
# ...             ...    ...          ...           ...          ...
# 13500          0.77   2238   10071000.0       10071.0  9970.071429
# 13501          1.47   1377    6196500.0        6196.5  6591.857143
# 13502          2.02    654    2943000.0        2943.0  2649.857143
# 13503          1.59    259    1165500.0        1165.5  1021.500000
# 13504          0.83    194     873000.0         873.0   799.714286
#
#            kPAR_14d         DIN     DIN:SRP    DIN:SI    SRP:SI     IM [Jm2d]  \
# 0               NaN   55.357143   33.648459  2.743363  0.081530  4.496419e+05
# 1       1497.857143   77.678571   87.278775  3.945211  0.059029  2.713500e+06
# 2       2865.857143  100.000000  140.909091  5.147059  0.036528  2.443494e+06
# 3       5926.821429   48.428571   60.051429  7.704545  0.128299  6.709149e+06
# 4       9416.892857    2.285714    1.968254  1.333333  0.677419  5.799802e+06
# ...             ...         ...         ...       ...       ...           ...
# 13500  10099.285714    0.571429    0.989625  0.903955  0.913432  1.007100e+07
# 13501   5372.678571    2.878571   15.124697  2.257703  0.149273  6.027189e+06
# 13502   2390.785714    0.964286    4.670759  0.573248  0.122731  2.942999e+06
# 13503   1665.321429    7.464286   17.014181  2.069307  0.121622  1.165497e+06
# 13504    808.714286    9.128571   20.807773  2.600203  0.124963  8.729864e+05
#
#             Agl       Dbr       Ezo       Gde       Oau       Omo       Orh  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      3.271842  4.748777  3.572755  3.572755  4.313065  3.748808  3.572755
# 4      4.669596       NaN  3.271842  3.970672       NaN  2.670246  1.973128
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Osi       Ram       Rse       Tec       Tle       Tni       Tro  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      3.873785  3.271842  3.271842  3.572755  3.572755  4.669596  4.475787
# 4           NaN       NaN  5.192467       NaN       NaN       NaN  4.012035
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        Dle  Etr  Gfl       Gsp       Nsc       Pbi  Pbr  Pha  Stu       Kgl  \
# 0      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 1      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 2      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 3      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 4      NaN  NaN  NaN  3.669689  3.271842  3.669689  NaN  NaN  NaN  1.973128
# ...    ...  ...  ...       ...       ...       ...  ...  ...  ...       ...
# 13500  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13501  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13502  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13503  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13504  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
#
#        ...  Cfu  Cgr  Lan  Pcl  Pmi  Pos  Pse  Cden  Aco  Dip  Csu  Mnu  Pco  \
# 0      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 2      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 3      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 4      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...  ...  ...
# 13500  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13501  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13502  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13503  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 13504  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
#
#        Cdeb  Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  Gfa  \
# 0       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Hta  Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  Mpe  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Pde  Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [13505 rows x 106 columns]

# %% [markdown]
# #### Annotate interpolated values

# %%
def list_interpolated_columns(row, missing_mask):
    interpolated_columns = [col for col in merged_df[interpolation_columns].columns if missing_mask.loc[row.name, col]]
    return interpolated_columns 

merged_interpolated['interpolated_columns'] = merged_interpolated.apply(lambda row: list_interpolated_columns(row, missing_mask), axis=1)

# %%
merged_interpolated
# Out:
#        LOC_CODE       DATUM      TIJD  ZS [mg/l]  ZICHT [dm]  T [oC]  \
# 0       DANTZGT  1990-01-10  15:00:00     135.00         2.0     4.0
# 1       DANTZGT  1990-02-06  13:40:00     295.00         0.5     6.0
# 2       DANTZGT  1990-03-08  13:45:00     103.00         3.0     7.3
# 3       DANTZGT  1990-04-04  10:00:00     113.00         3.0     8.2
# 4       DANTZGT  1990-05-09  15:30:00      20.00        11.0    17.4
# ...         ...         ...       ...        ...         ...     ...
# 13500  WALCRN70  2020-08-13  05:04:00       4.02         NaN    18.5
# 13501  WALCRN70  2020-09-16  09:30:00       4.52         NaN    18.5
# 13502  WALCRN70  2020-10-14  08:25:00       4.99         NaN    15.7
# 13503  WALCRN70  2020-11-17  05:58:00       3.92         NaN    13.9
# 13504  WALCRN70  2020-12-16  10:04:00       6.06         NaN    11.6
#
#        SiO2 [umol/L]  SALNTT [DIMSLS]  PO4 [umol/L]  pH [DIMSLS]  \
# 0          20.178571            29.19      1.645161         7.80
# 1          19.803571            27.37      1.177419         7.90
# 2          19.428571            24.99      0.709677         8.00
# 3           6.285714            28.79      0.806452         8.10
# 4           1.714286            33.28      1.161290         8.30
# ...              ...              ...           ...          ...
# 13500       0.632143            35.00      0.577419         8.00
# 13501       1.275000            34.80      0.190323         7.97
# 13502       1.682143            34.90      0.206452         8.11
# 13503       3.607143            35.00      0.438710         8.13
# 13504       3.510714            35.00      0.438710         7.89
#
#        NO3 [umol/L]  NO2 [umol/L]  NH4 [umol/L]     E [/m]  E_method  \
# 0         37.571429      3.714286     14.071429   0.751180     2012a
# 1         63.428571      2.892857     11.357143  11.391822     2012b
# 2         89.285714      2.071429      8.642857   1.364080     2012a
# 3         40.000000      2.000000      6.428571   1.037580     2012a
# 4          0.214286      0.142857      1.928571   0.738760     2012a
# ...             ...           ...           ...        ...       ...
# 13500      0.357143      0.035714      0.178571   0.541120     2012a
# 13501      2.278571      0.114286      0.485714   0.120000  measured
# 13502      0.357143      0.242857      0.364286   0.488420     2012a
# 13503      6.442857      0.842857      0.178571   0.431040     2012a
# 13504      8.785714      0.164286      0.178571   0.368980     2012a
#
#        CHLFa [ug/l]      Q  PAR [J/m2d]  PAR [kJ/m2d]      kPAR_7d  \
# 0              1.30    100     450000.0         450.0   513.000000
# 1             11.20    603    2713500.0        2713.5  1737.000000
# 2             21.10    543    2443500.0        2443.5  2949.428571
# 3             25.00   1491    6709500.0        6709.5  6508.285714
# 4             10.20   1290    5805000.0        5805.0  9470.571429
# ...             ...    ...          ...           ...          ...
# 13500          0.77   2238   10071000.0       10071.0  9970.071429
# 13501          1.47   1377    6196500.0        6196.5  6591.857143
# 13502          2.02    654    2943000.0        2943.0  2649.857143
# 13503          1.59    259    1165500.0        1165.5  1021.500000
# 13504          0.83    194     873000.0         873.0   799.714286
#
#            kPAR_14d         DIN     DIN:SRP    DIN:SI    SRP:SI     IM [Jm2d]  \
# 0               NaN   55.357143   33.648459  2.743363  0.081530  4.496419e+05
# 1       1497.857143   77.678571   87.278775  3.945211  0.059029  2.713500e+06
# 2       2865.857143  100.000000  140.909091  5.147059  0.036528  2.443494e+06
# 3       5926.821429   48.428571   60.051429  7.704545  0.128299  6.709149e+06
# 4       9416.892857    2.285714    1.968254  1.333333  0.677419  5.799802e+06
# ...             ...         ...         ...       ...       ...           ...
# 13500  10099.285714    0.571429    0.989625  0.903955  0.913432  1.007100e+07
# 13501   5372.678571    2.878571   15.124697  2.257703  0.149273  6.027189e+06
# 13502   2390.785714    0.964286    4.670759  0.573248  0.122731  2.942999e+06
# 13503   1665.321429    7.464286   17.014181  2.069307  0.121622  1.165497e+06
# 13504    808.714286    9.128571   20.807773  2.600203  0.124963  8.729864e+05
#
#             Agl       Dbr       Ezo       Gde       Oau       Omo       Orh  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      3.271842  4.748777  3.572755  3.572755  4.313065  3.748808  3.572755
# 4      4.669596       NaN  3.271842  3.970672       NaN  2.670246  1.973128
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#             Osi       Ram       Rse       Tec       Tle       Tni       Tro  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      3.873785  3.271842  3.271842  3.572755  3.572755  4.669596  4.475787
# 4           NaN       NaN  5.192467       NaN       NaN       NaN  4.012035
# ...         ...       ...       ...       ...       ...       ...       ...
# 13500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13504       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        Dle  Etr  Gfl       Gsp       Nsc       Pbi  Pbr  Pha  Stu       Kgl  \
# 0      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 1      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 2      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 3      NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 4      NaN  NaN  NaN  3.669689  3.271842  3.669689  NaN  NaN  NaN  1.973128
# ...    ...  ...  ...       ...       ...       ...  ...  ...  ...       ...
# 13500  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13501  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13502  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13503  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
# 13504  NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN  NaN       NaN
#
#        ...  Cgr  Lan  Pcl  Pmi  Pos  Pse  Cden  Aco  Dip  Csu  Mnu  Pco  Cdeb  \
# 0      ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1      ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2      ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 3      ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 4      ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# ...    ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 13500  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13501  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13502  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13503  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13504  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
#        Cwa  Pba  Dac  Ptr  Lun  Nsi  Rst  Pst  Acn  Tno  Ccu  Pan  Gfa  Hta  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Dsp  Psu  Cei  Ndi  Cda  Dro  Cha  Pac  Cau  Coc  Pte  Edu  Mpe  Pde  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        Plo  Dpu  Rte  Fja  Hak  Mhe  Dno  Dat  \
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...
# 13500  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13502  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13504  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                     interpolated_columns
# 0                                                     []
# 1      [SiO2 [umol/L], PO4 [umol/L], pH [DIMSLS], NO3...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13500                                                 []
# 13501                                                 []
# 13502                                                 []
# 13503                                                 []
# 13504                                                 []
#
# [13505 rows x 107 columns]

# %% [markdown]
# ### Write merged data to excel file

# %%
filename = '../../data/MERGED_DATA_180624.xlsx'
sheetname = 'MERGE_FINAL'

with pd.ExcelWriter(filename, mode='w') as writer:  
    merged_interpolated.to_excel(writer, sheet_name=sheetname, index=False)

print(f"Data written to sheet '{sheetname}' in '{filename}'")
# Out:
# Data written to sheet 'MERGE_FINAL' in '../../data/MERGED_DATA_180624.xlsx'
